# %%
# Necessary Imports
import json
import random
import torch
import gc
import re

import pandas as pd
import numpy as np

from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer, AutoTokenizer
from datasets import Dataset, DatasetDict
from sklearn.metrics import f1_score
from transformers import DataCollatorWithPadding

# %%
# The text is clustered in the following labels
encoded_rr = {
    "PREAMBLE":0,
    "FAC":1,
    "RLC":2,
    "ISSUE":3,
    "ARG_PETITIONER":4,
    "ARG_RESPONDENT":5,
    "ANALYSIS":6,
    "STA":7,
    "PRE_RELIED":8,
    "PRE_NOT_RELIED":9,
    "RATIO":10,
    "RPC":11,
    "NONE":12
}

id2label = {
    0:"PREAMBLE",
    1:"FAC",
    2:"RLC",
    3:"ISSUE",
    4:"ARG_PETITIONER",
    5:"ARG_RESPONDENT",
    6:"ANALYSIS",
    7:"STA",
    8:"PRE_RELIED",
    9:"PRE_NOT_RELIED",
    10:"RATIO",
    11:"RPC",
    12:"NONE"
}

# %%
d = open('rr_dev.json')
t = open('train.json')
dev_dataset = json.load(d)
train_dataset = json.load(t)

# %%
# Combining the dev and train dataset and then splitting it into train and test of 70:30 ratio
train_dataset.extend(dev_dataset)
random.shuffle(train_dataset)
print("Total size:  %d"%(len(train_dataset)))
split = (len(train_dataset)*7)//10 
print('Splitting data from 0 to %d for train' % (split))
print('Splitting data from %d to %d for test' % (split,len(train_dataset)))
train = train_dataset[:split]
test = train_dataset[split:]
# Out:
# Total size:  277
# Splitting data from 0 to 193 for train
# Splitting data from 193 to 277 for test

# %%
train_data = []
test_data = []

for rec in test:
  for ele in rec['annotations'][0]['result']: 
    processed_text = ele['value']['text']
    processed_text = processed_text.replace('\n', ' ')
    processed_text = re.sub(' {2,}', ' ', processed_text)
    processed_text = processed_text.lower()
    test_data.append({"label":encoded_rr[ele['value']['labels'][0]],"text": processed_text})

for rec in train:
  for ele in rec['annotations'][0]['result']:
    processed_text = ele['value']['text']
    processed_text = processed_text.replace('\n', ' ')
    processed_text = re.sub(' {2,}', ' ', processed_text)
    processed_text = processed_text.lower() 
    train_data.append({"label":encoded_rr[ele['value']['labels'][0]],"text": processed_text})

# %%
train_data[0]['aux_text'] = ""
test_data[0]['aux_text'] = ""
for i in range(1, len(train_data)):
    train_data[i]['aux_text'] = train_data[i-1]['text']
for i in range(1, len(test_data)):
    test_data[i]['aux_text'] = test_data[i-1]['text']

# %%
model = AutoModelForSequenceClassification.from_pretrained("law-ai/InLegalBERT", num_labels=13,label2id=encoded_rr,id2label=id2label)
tokenizer = AutoTokenizer.from_pretrained("law-ai/InLegalBERT")
# Out:
# Downloading: 100%|██████████| 671/671 [00:00<00:00, 1.18MB/s]
# Downloading: 100%|██████████| 510M/510M [00:47<00:00, 11.3MB/s]
# Some weights of the model checkpoint at law-ai/InLegalBERT were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at law-ai/InLegalBERT and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading: 100%|██████████| 516/516 [00:00<00:00, 421kB/s]
# Downloading: 100%|██████████| 217k/217k [00:00<00:00, 2.27MB/s]
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 87.6kB/s]

# %%
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)

# %%
test_df = Dataset.from_pandas(pd.DataFrame.from_records(test_data))
train_df = Dataset.from_pandas(pd.DataFrame.from_records(train_data))
dataset = DatasetDict({"train":train_df,"test":test_df})
tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# 100%|██████████| 23/23 [00:01<00:00, 22.02ba/s]
# 100%|██████████| 10/10 [00:00<00:00, 24.48ba/s]

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
def compute_metrics(eval_preds):
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)
    return {'f1':f1_score(y_true=labels, y_pred=predictions,average='micro')}

# %%
training_args = TrainingArguments(
    output_dir="./resultsInlegalBERT",
    # overwrite_output_dir=True,
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
    save_strategy='steps',
    save_steps=2000,
    evaluation_strategy='steps',
    eval_steps=1000,
    
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['test'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

trainer.train()

gc.collect()
torch.cuda.empty_cache()
# Out:
# The following columns in the training set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /h/users/ssure044/rhetorical_roles/venv/lib/python3.6/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 22202
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 13880
#     <div>
#
#       <progress value='10853' max='13880' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10853/13880 38:09 < 10:38, 4.74 it/s, Epoch 3.91/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.171900</td>
#       <td>1.156417</td>
#       <td>0.642761</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.097400</td>
#       <td>1.124946</td>
#       <td>0.640795</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.980900</td>
#       <td>1.158272</td>
#       <td>0.634586</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.889100</td>
#       <td>1.085436</td>
#       <td>0.653006</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.821500</td>
#       <td>1.215878</td>
#       <td>0.627341</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.642500</td>
#       <td>1.274375</td>
#       <td>0.621236</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.638200</td>
#       <td>1.253493</td>
#       <td>0.638518</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.643300</td>
#       <td>1.245121</td>
#       <td>0.634275</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.473200</td>
#       <td>1.365753</td>
#       <td>0.633861</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.465700</td>
#       <td>1.416671</td>
#       <td>0.639967</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# Saving model checkpoint to ./resultsInlegalBERT/checkpoint-2000
# Configuration saved in ./resultsInlegalBERT/checkpoint-2000/config.json
# Model weights saved in ./resultsInlegalBERT/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./resultsInlegalBERT/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./resultsInlegalBERT/checkpoint-2000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# Saving model checkpoint to ./resultsInlegalBERT/checkpoint-4000
# Configuration saved in ./resultsInlegalBERT/checkpoint-4000/config.json
# Model weights saved in ./resultsInlegalBERT/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./resultsInlegalBERT/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./resultsInlegalBERT/checkpoint-4000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# Saving model checkpoint to ./resultsInlegalBERT/checkpoint-6000
# Configuration saved in ./resultsInlegalBERT/checkpoint-6000/config.json
# Model weights saved in ./resultsInlegalBERT/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./resultsInlegalBERT/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./resultsInlegalBERT/checkpoint-6000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# Saving model checkpoint to ./resultsInlegalBERT/checkpoint-8000
# Configuration saved in ./resultsInlegalBERT/checkpoint-8000/config.json
# Model weights saved in ./resultsInlegalBERT/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./resultsInlegalBERT/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./resultsInlegalBERT/checkpoint-8000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: aux_text, text. If aux_text, text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 9663
#   Batch size = 8
# Saving model checkpoint to ./resultsInlegalBERT/checkpoint-10000
# Configuration saved in ./resultsInlegalBERT/checkpoint-10000/config.json
# Model weights saved in ./resultsInlegalBERT/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./resultsInlegalBERT/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./resultsInlegalBERT/checkpoint-10000/special_tokens_map.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7b0409fb94b6> in <module>
#      24 )
#      25
# ---> 26 trainer.train()
#      27
#      28 gc.collect()
#
# ~/rhetorical_roles/venv/lib/python3.6/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1425                     args.logging_nan_inf_filter
#    1426                     and not is_torch_tpu_available()
# -> 1427                     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1428                 ):
#    1429                     # if loss is nan or inf simply add the average of previous logged losses
#
# KeyboardInterrupt:

# %%
id2label = {
    0:"PREAMBLE",
    1:"FAC",
    2:"RLC",
    3:"ISSUE",
    4:"ARG_PETITIONER",
    5:"ARG_RESPONDENT",
    6:"ANALYSIS",
    7:"STA",
    8:"PRE_RELIED",
    9:"PRE_NOT_RELIED",
    10:"RATIO",
    11:"RPC",
    12:"NONE"
}

# %%
model1 = AutoModelForSequenceClassification.from_pretrained("./resultsInlegalBERT/checkpoint-4000/", num_labels=13,label2id=encoded_rr,id2label=id2label)
tokenizer1 = AutoTokenizer.from_pretrained("./resultsInlegalBERT/checkpoint-4000/")
# Out:
# loading configuration file ./resultsInlegalBERT/checkpoint-4000/config.json
# Model config BertConfig {
#   "_name_or_path": "./resultsInlegalBERT/checkpoint-4000/",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_ids": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "PREAMBLE",
#     "1": "FAC",
#     "2": "RLC",
#     "3": "ISSUE",
#     "4": "ARG_PETITIONER",
#     "5": "ARG_RESPONDENT",
#     "6": "ANALYSIS",
#     "7": "STA",
#     "8": "PRE_RELIED",
#     "9": "PRE_NOT_RELIED",
#     "10": "RATIO",
#     "11": "RPC",
#     "12": "NONE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "ANALYSIS": 6,
#     "ARG_PETITIONER": 4,
#     "ARG_RESPONDENT": 5,
#     "FAC": 1,
#     "ISSUE": 3,
#     "NONE": 12,
#     "PREAMBLE": 0,
#     "PRE_NOT_RELIED": 9,
#     "PRE_RELIED": 8,
#     "RATIO": 10,
#     "RLC": 2,
#     "RPC": 11,
#     "STA": 7
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file ./resultsInlegalBERT/checkpoint-4000/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at ./resultsInlegalBERT/checkpoint-4000/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.
# Didn't find file ./resultsInlegalBERT/checkpoint-4000/added_tokens.json. We won't load it.
# loading file ./resultsInlegalBERT/checkpoint-4000/vocab.txt
# loading file ./resultsInlegalBERT/checkpoint-4000/tokenizer.json
# loading file None
# loading file ./resultsInlegalBERT/checkpoint-4000/special_tokens_map.json
# loading file ./resultsInlegalBERT/checkpoint-4000/tokenizer_config.json

# %%
def preprocessrr_function(examples):
    return tokenizer1(examples["text"], truncation=True,return_tensors='pt')

# %%
rr_test = open('rr_test.json')
rrtest_dataset = json.load(rr_test)
rrtest_data = []

for rec in rrtest_dataset:
  for ele in rec['annotations'][0]['result']: 
    processed_text = ele['value']['text']
    processed_text = processed_text.replace('\n', ' ')
    processed_text = re.sub(' {2,}', ' ', processed_text)
    processed_text = processed_text.lower()
    rrtest_data.append({"text": processed_text})

# rrtest_data[0]['aux_text'] = ""
# for i in range(1,len(rrtest_data)):
#   rrtest_data[i]['aux_text'] = rrtest_data[i-1]['text']

# rrtest_df = Dataset.from_pandas(pd.DataFrame.from_records(rrtest_data))
# rrtest_dataset = rrtest_df.map(preprocessrr_function)

# %%
tdata = [[i['aux_text'],i['text']]for i in rrtest_data]
rrtest_dataset = tokenizer1(tdata[:1000], truncation=True,padding=True, return_tensors='pt')

# %%
len(rrtest_dataset['input_ids'])
# Out:
# 1000

# %%
tdata = [i['text'] for i in rrtest_data]
tdata

# %%
from transformers import pipeline

pipe = pipeline(task='text-classification', model =model1, tokenizer=tokenizer1,device=0)
pipe(tdata[:2])
# Out:
# [{'label': 'PREAMBLE', 'score': 0.9895686507225037},
#  {'label': 'PREAMBLE', 'score': 0.9906486868858337}]

# %%
output = pipe(tdata,padding=True, truncation=True)
with open('op.txt','w+') as f:
    f.write(str(output))

# %%
output
# Out:
# [{'label': 'PREAMBLE', 'score': 0.9895686507225037},
#  {'label': 'PREAMBLE', 'score': 0.9906486868858337},
#  {'label': 'PREAMBLE', 'score': 0.9823678731918335},
#  {'label': 'PREAMBLE', 'score': 0.9919686913490295},
#  {'label': 'PREAMBLE', 'score': 0.99114990234375},
#  {'label': 'PREAMBLE', 'score': 0.9906103014945984},
#  {'label': 'PREAMBLE', 'score': 0.9911736845970154},
#  {'label': 'PREAMBLE', 'score': 0.9908678531646729},
#  {'label': 'PREAMBLE', 'score': 0.7254161238670349},
#  {'label': 'NONE', 'score': 0.8613502979278564},
#  {'label': 'PREAMBLE', 'score': 0.9116681814193726},
#  {'label': 'FAC', 'score': 0.8108745813369751},
#  {'label': 'PREAMBLE', 'score': 0.9754899740219116},
#  {'label': 'FAC', 'score': 0.9437655210494995},
#  {'label': 'FAC', 'score': 0.9306872487068176},
#  {'label': 'FAC', 'score': 0.9502750635147095},
#  {'label': 'FAC', 'score': 0.6308172941207886},
#  {'label': 'ARG_PETITIONER', 'score': 0.40371522307395935},
#  {'label': 'ARG_PETITIONER', 'score': 0.48923760652542114},
#  {'label': 'ARG_PETITIONER', 'score': 0.33042579889297485},
#  {'label': 'ARG_PETITIONER', 'score': 0.3083378076553345},
#  {'label': 'ANALYSIS', 'score': 0.5121392011642456},
#  {'label': 'NONE', 'score': 0.8877455592155457},
#  {'label': 'FAC', 'score': 0.32884645462036133},
#  {'label': 'ARG_PETITIONER', 'score': 0.3430936932563782},
#  {'label': 'ARG_PETITIONER', 'score': 0.574567437171936},
#  {'label': 'ARG_PETITIONER', 'score': 0.5745989680290222},
#  {'label': 'PREAMBLE', 'score': 0.7946066856384277},
#  {'label': 'ARG_PETITIONER', 'score': 0.5846708416938782},
#  {'label': 'ARG_PETITIONER', 'score': 0.5161578059196472},
#  {'label': 'ARG_PETITIONER', 'score': 0.5453936457633972},
#  {'label': 'ARG_PETITIONER', 'score': 0.4534240961074829},
#  {'label': 'ARG_RESPONDENT', 'score': 0.4542092978954315},
#  {'label': 'RATIO', 'score': 0.39322954416275024},
#  {'label': 'ANALYSIS', 'score': 0.7084726691246033},
#  {'label': 'ANALYSIS', 'score': 0.48659828305244446},
#  {'label': 'RATIO', 'score': 0.42131707072257996},
#  {'label': 'ANALYSIS', 'score': 0.5079653859138489},
#  {'label': 'PRE_RELIED', 'score': 0.6023948788642883},
#  {'label': 'ANALYSIS', 'score': 0.8917134404182434},
#  {'label': 'PRE_RELIED', 'score': 0.7556101083755493},
#  {'label': 'ANALYSIS', 'score': 0.8617146015167236},
#  {'label': 'ANALYSIS', 'score': 0.8626177906990051},
#  {'label': 'ANALYSIS', 'score': 0.42491742968559265},
#  {'label': 'ANALYSIS', 'score': 0.6027531027793884},
#  {'label': 'ANALYSIS', 'score': 0.9371488690376282},
#  {'label': 'ARG_PETITIONER', 'score': 0.5960168838500977},
#  {'label': 'PRE_RELIED', 'score': 0.7305904030799866},
#  {'label': 'ANALYSIS', 'score': 0.8390682339668274},
#  {'label': 'ANALYSIS', 'score': 0.699070394039154},
#  {'label': 'ANALYSIS', 'score': 0.6874288320541382},
#  {'label': 'ANALYSIS', 'score': 0.8192188143730164},
#  {'label': 'ANALYSIS', 'score': 0.766362726688385},
#  {'label': 'ANALYSIS', 'score': 0.695440948009491},
#  {'label': 'ANALYSIS', 'score': 0.8027667999267578},
#  {'label': 'ANALYSIS', 'score': 0.5720406174659729},
#  {'label': 'ANALYSIS', 'score': 0.4829317331314087},
#  {'label': 'RATIO', 'score': 0.7079645991325378},
#  {'label': 'RPC', 'score': 0.8999848961830139},
#  {'label': 'RPC', 'score': 0.9196769595146179},
#  {'label': 'NONE', 'score': 0.9667660593986511},
#  {'label': 'PREAMBLE', 'score': 0.99000483751297},
#  {'label': 'PREAMBLE', 'score': 0.976491391658783},
#  {'label': 'PREAMBLE', 'score': 0.9904688000679016},
#  {'label': 'PREAMBLE', 'score': 0.9806220531463623},
#  {'label': 'PREAMBLE', 'score': 0.9917106628417969},
#  {'label': 'PREAMBLE', 'score': 0.7856890559196472},
#  {'label': 'PREAMBLE', 'score': 0.9355807900428772},
#  {'label': 'PREAMBLE', 'score': 0.9910921454429626},
#  {'label': 'PREAMBLE', 'score': 0.9877898693084717},
#  {'label': 'FAC', 'score': 0.9635943174362183},
#  {'label': 'FAC', 'score': 0.9607353806495667},
#  {'label': 'FAC', 'score': 0.9169864058494568},
#  {'label': 'FAC', 'score': 0.9375950694084167},
#  {'label': 'FAC', 'score': 0.6725093126296997},
#  {'label': 'FAC', 'score': 0.8522076606750488},
#  {'label': 'FAC', 'score': 0.7798382043838501},
#  {'label': 'FAC', 'score': 0.9377825856208801},
#  {'label': 'FAC', 'score': 0.9429328441619873},
#  {'label': 'FAC', 'score': 0.9408248662948608},
#  {'label': 'ISSUE', 'score': 0.947974443435669},
#  {'label': 'ISSUE', 'score': 0.8961707353591919},
#  {'label': 'ISSUE', 'score': 0.9215973615646362},
#  {'label': 'ISSUE', 'score': 0.9473282694816589},
#  {'label': 'FAC', 'score': 0.591744601726532},
#  {'label': 'ANALYSIS', 'score': 0.9107339382171631},
#  {'label': 'ANALYSIS', 'score': 0.8561604619026184},
#  {'label': 'ANALYSIS', 'score': 0.8393838405609131},
#  {'label': 'ANALYSIS', 'score': 0.7347985506057739},
#  {'label': 'FAC', 'score': 0.8849503397941589},
#  {'label': 'ANALYSIS', 'score': 0.9077173471450806},
#  {'label': 'ANALYSIS', 'score': 0.9086741209030151},
#  {'label': 'ANALYSIS', 'score': 0.916806697845459},
#  {'label': 'ANALYSIS', 'score': 0.7466446757316589},
#  {'label': 'ANALYSIS', 'score': 0.8816611170768738},
#  {'label': 'ANALYSIS', 'score': 0.9055823087692261},
#  {'label': 'ANALYSIS', 'score': 0.7202743291854858},
#  {'label': 'ANALYSIS', 'score': 0.7763904929161072},
#  {'label': 'ANALYSIS', 'score': 0.7456744313240051},
#  {'label': 'ANALYSIS', 'score': 0.7205894589424133},
#  {'label': 'ANALYSIS', 'score': 0.6807971596717834},
#  {'label': 'ANALYSIS', 'score': 0.5292590260505676},
#  {'label': 'ANALYSIS', 'score': 0.9338761568069458},
#  {'label': 'ANALYSIS', 'score': 0.7347985506057739},
#  {'label': 'ANALYSIS', 'score': 0.8328019976615906},
#  {'label': 'ANALYSIS', 'score': 0.787276029586792},
#  {'label': 'ANALYSIS', 'score': 0.8521738052368164},
#  {'label': 'ANALYSIS', 'score': 0.8958823680877686},
#  {'label': 'ANALYSIS', 'score': 0.6434586644172668},
#  {'label': 'ANALYSIS', 'score': 0.7573569416999817},
#  {'label': 'RATIO', 'score': 0.6841374039649963},
#  {'label': 'RPC', 'score': 0.9156385660171509},
#  {'label': 'RPC', 'score': 0.9552867412567139},
#  {'label': 'RPC', 'score': 0.9534568786621094},
#  {'label': 'RPC', 'score': 0.9443590044975281},
#  {'label': 'NONE', 'score': 0.9625107049942017},
#  {'label': 'NONE', 'score': 0.9431545734405518},
#  {'label': 'NONE', 'score': 0.9691721200942993},
#  {'label': 'NONE', 'score': 0.978748619556427},
#  {'label': 'NONE', 'score': 0.9644120335578918},
#  {'label': 'NONE', 'score': 0.9767680168151855},
#  {'label': 'NONE', 'score': 0.9778252243995667},
#  {'label': 'NONE', 'score': 0.9620478749275208},
#  {'label': 'PREAMBLE', 'score': 0.9863755106925964},
#  {'label': 'PREAMBLE', 'score': 0.990921676158905},
#  {'label': 'PREAMBLE', 'score': 0.9891913533210754},
#  {'label': 'FAC', 'score': 0.9710025191307068},
#  {'label': 'FAC', 'score': 0.9750421047210693},
#  {'label': 'FAC', 'score': 0.9129547476768494},
#  {'label': 'FAC', 'score': 0.9670087099075317},
#  {'label': 'FAC', 'score': 0.8639826774597168},
#  {'label': 'ISSUE', 'score': 0.9554002285003662},
#  {'label': 'FAC', 'score': 0.7099247574806213},
#  {'label': 'ANALYSIS', 'score': 0.709356427192688},
#  {'label': 'ANALYSIS', 'score': 0.853219211101532},
#  {'label': 'ANALYSIS', 'score': 0.6027429103851318},
#  {'label': 'ANALYSIS', 'score': 0.7347928285598755},
#  {'label': 'ANALYSIS', 'score': 0.8146670460700989},
#  {'label': 'ANALYSIS', 'score': 0.7764028310775757},
#  {'label': 'ANALYSIS', 'score': 0.8497834205627441},
#  {'label': 'ANALYSIS', 'score': 0.5518384575843811},
#  {'label': 'ANALYSIS', 'score': 0.726320743560791},
#  {'label': 'ANALYSIS', 'score': 0.6645830273628235},
#  {'label': 'ANALYSIS', 'score': 0.7506465315818787},
#  {'label': 'ANALYSIS', 'score': 0.616658627986908},
#  {'label': 'ANALYSIS', 'score': 0.9056831002235413},
#  {'label': 'ANALYSIS', 'score': 0.5635349750518799},
#  {'label': 'ANALYSIS', 'score': 0.7610064148902893},
#  {'label': 'ANALYSIS', 'score': 0.46224135160446167},
#  {'label': 'PRE_RELIED', 'score': 0.6620257496833801},
#  {'label': 'RATIO', 'score': 0.6052121520042419},
#  {'label': 'RPC', 'score': 0.8850019574165344},
#  {'label': 'RPC', 'score': 0.9568461775779724},
#  {'label': 'RPC', 'score': 0.9443590044975281},
#  {'label': 'NONE', 'score': 0.7731851935386658},
#  {'label': 'RPC', 'score': 0.9603113532066345},
#  {'label': 'NONE', 'score': 0.7731851935386658},
#  {'label': 'NONE', 'score': 0.9278756976127625},
#  {'label': 'NONE', 'score': 0.972652018070221},
#  {'label': 'NONE', 'score': 0.7731851935386658},
#  {'label': 'NONE', 'score': 0.9769675731658936},
#  {'label': 'NONE', 'score': 0.9313793778419495},
#  {'label': 'NONE', 'score': 0.9794479012489319},
#  {'label': 'PREAMBLE', 'score': 0.988167941570282},
#  {'label': 'PREAMBLE', 'score': 0.89438396692276},
#  {'label': 'PREAMBLE', 'score': 0.9183302521705627},
#  {'label': 'PREAMBLE', 'score': 0.9910542368888855},
#  {'label': 'PREAMBLE', 'score': 0.9843890070915222},
#  {'label': 'PREAMBLE', 'score': 0.9892421364784241},
#  {'label': 'PREAMBLE', 'score': 0.9865813255310059},
#  {'label': 'NONE', 'score': 0.7797879576683044},
#  {'label': 'PREAMBLE', 'score': 0.9888601899147034},
#  {'label': 'PREAMBLE', 'score': 0.9836764931678772},
#  {'label': 'PREAMBLE', 'score': 0.9910780787467957},
#  {'label': 'PREAMBLE', 'score': 0.5081918835639954},
#  {'label': 'PREAMBLE', 'score': 0.9877139329910278},
#  {'label': 'FAC', 'score': 0.9444392919540405},
#  {'label': 'FAC', 'score': 0.9697360992431641},
#  {'label': 'FAC', 'score': 0.6214295625686646},
#  {'label': 'ANALYSIS', 'score': 0.4692738652229309},
#  {'label': 'FAC', 'score': 0.9031864404678345},
#  {'label': 'FAC', 'score': 0.8531720042228699},
#  {'label': 'FAC', 'score': 0.88926762342453},
#  {'label': 'FAC', 'score': 0.7604480385780334},
#  {'label': 'FAC', 'score': 0.6295506358146667},
#  {'label': 'FAC', 'score': 0.95745849609375},
#  {'label': 'FAC', 'score': 0.9093395471572876},
#  {'label': 'ISSUE', 'score': 0.9571889638900757},
#  {'label': 'ISSUE', 'score': 0.953745424747467},
#  {'label': 'ISSUE', 'score': 0.9413543343544006},
#  {'label': 'ANALYSIS', 'score': 0.46051546931266785},
#  {'label': 'FAC', 'score': 0.5338282585144043},
#  {'label': 'ANALYSIS', 'score': 0.5682826638221741},
#  {'label': 'ANALYSIS', 'score': 0.7041884064674377},
#  {'label': 'FAC', 'score': 0.6214295625686646},
#  {'label': 'ANALYSIS', 'score': 0.4692738652229309},
#  {'label': 'FAC', 'score': 0.9031864404678345},
#  {'label': 'FAC', 'score': 0.8531720042228699},
#  {'label': 'FAC', 'score': 0.88926762342453},
#  {'label': 'FAC', 'score': 0.7604480385780334},
#  {'label': 'ANALYSIS', 'score': 0.7402430772781372},
#  {'label': 'ARG_PETITIONER', 'score': 0.47018924355506897},
#  {'label': 'ANALYSIS', 'score': 0.622482180595398},
#  {'label': 'ANALYSIS', 'score': 0.7590104937553406},
#  {'label': 'ARG_PETITIONER', 'score': 0.6212180852890015},
#  {'label': 'RATIO', 'score': 0.7260611057281494},
#  {'label': 'ARG_PETITIONER', 'score': 0.3980543315410614},
#  {'label': 'ARG_PETITIONER', 'score': 0.5191644430160522},
#  {'label': 'ANALYSIS', 'score': 0.8039340972900391},
#  {'label': 'ANALYSIS', 'score': 0.918530285358429},
#  {'label': 'ANALYSIS', 'score': 0.7513499855995178},
#  {'label': 'ANALYSIS', 'score': 0.9210494756698608},
#  {'label': 'ANALYSIS', 'score': 0.8100268244743347},
#  {'label': 'ANALYSIS', 'score': 0.9009978175163269},
#  {'label': 'ANALYSIS', 'score': 0.8742870092391968},
#  {'label': 'ANALYSIS', 'score': 0.867393970489502},
#  {'label': 'ANALYSIS', 'score': 0.9342377781867981},
#  {'label': 'ANALYSIS', 'score': 0.9301351308822632},
#  {'label': 'ANALYSIS', 'score': 0.6949317455291748},
#  {'label': 'RPC', 'score': 0.9196491241455078},
#  {'label': 'RPC', 'score': 0.93282550573349},
#  {'label': 'RPC', 'score': 0.9442965984344482},
#  {'label': 'NONE', 'score': 0.6227985620498657},
#  {'label': 'NONE', 'score': 0.9581157565116882},
#  {'label': 'NONE', 'score': 0.9351227283477783},
#  {'label': 'NONE', 'score': 0.9745368957519531},
#  {'label': 'NONE', 'score': 0.9653051495552063},
#  {'label': 'NONE', 'score': 0.9462217688560486},
#  {'label': 'NONE', 'score': 0.9781129956245422},
#  {'label': 'NONE', 'score': 0.9786399602890015},
#  {'label': 'NONE', 'score': 0.9762547016143799},
#  {'label': 'NONE', 'score': 0.9745752811431885},
#  {'label': 'NONE', 'score': 0.9724417328834534},
#  {'label': 'NONE', 'score': 0.9682498574256897},
#  {'label': 'PREAMBLE', 'score': 0.9896876215934753},
#  {'label': 'PREAMBLE', 'score': 0.9923242330551147},
#  {'label': 'PREAMBLE', 'score': 0.9876848459243774},
#  {'label': 'PREAMBLE', 'score': 0.9915825724601746},
#  {'label': 'PREAMBLE', 'score': 0.9900920987129211},
#  {'label': 'PREAMBLE', 'score': 0.9873933792114258},
#  {'label': 'PREAMBLE', 'score': 0.9895106554031372},
#  {'label': 'PREAMBLE', 'score': 0.7280368804931641},
#  {'label': 'PREAMBLE', 'score': 0.47980156540870667},
#  {'label': 'PREAMBLE', 'score': 0.962424099445343},
#  {'label': 'PREAMBLE', 'score': 0.9761683344841003},
#  {'label': 'FAC', 'score': 0.8965439796447754},
#  {'label': 'FAC', 'score': 0.9636718034744263},
#  {'label': 'ANALYSIS', 'score': 0.4538803696632385},
#  {'label': 'FAC', 'score': 0.943487286567688},
#  {'label': 'RLC', 'score': 0.5813248753547668},
#  {'label': 'FAC', 'score': 0.9142201542854309},
#  {'label': 'RPC', 'score': 0.5754858255386353},
#  {'label': 'ANALYSIS', 'score': 0.2986621558666229},
#  {'label': 'FAC', 'score': 0.7903913259506226},
#  {'label': 'FAC', 'score': 0.6590799689292908},
#  {'label': 'FAC', 'score': 0.6678323149681091},
#  {'label': 'ARG_PETITIONER', 'score': 0.5087995529174805},
#  {'label': 'ANALYSIS', 'score': 0.4934844970703125},
#  {'label': 'ARG_PETITIONER', 'score': 0.4440358877182007},
#  {'label': 'ARG_PETITIONER', 'score': 0.6536335349082947},
#  {'label': 'ARG_PETITIONER', 'score': 0.6810741424560547},
#  {'label': 'NONE', 'score': 0.9125291705131531},
#  {'label': 'PREAMBLE', 'score': 0.5587994456291199},
#  {'label': 'ARG_PETITIONER', 'score': 0.3107396364212036},
#  {'label': 'ARG_PETITIONER', 'score': 0.572492778301239},
#  {'label': 'ANALYSIS', 'score': 0.3253551423549652},
#  {'label': 'NONE', 'score': 0.4762739837169647},
#  {'label': 'ANALYSIS', 'score': 0.8379492163658142},
#  {'label': 'ARG_PETITIONER', 'score': 0.35647648572921753},
#  {'label': 'PRE_RELIED', 'score': 0.6749869585037231},
#  {'label': 'ANALYSIS', 'score': 0.7962762713432312},
#  {'label': 'ANALYSIS', 'score': 0.8841759562492371},
#  {'label': 'RPC', 'score': 0.7277948260307312},
#  {'label': 'ANALYSIS', 'score': 0.4752160608768463},
#  {'label': 'ANALYSIS', 'score': 0.7131747007369995},
#  {'label': 'PRE_RELIED', 'score': 0.4218975305557251},
#  {'label': 'ANALYSIS', 'score': 0.6830752491950989},
#  {'label': 'ANALYSIS', 'score': 0.629949152469635},
#  {'label': 'ANALYSIS', 'score': 0.6314153671264648},
#  {'label': 'PRE_RELIED', 'score': 0.6370616555213928},
#  {'label': 'PRE_RELIED', 'score': 0.6427505612373352},
#  {'label': 'PRE_RELIED', 'score': 0.6042314171791077},
#  {'label': 'ANALYSIS', 'score': 0.8408290147781372},
#  {'label': 'ANALYSIS', 'score': 0.8515259623527527},
#  {'label': 'ANALYSIS', 'score': 0.7652117013931274},
#  {'label': 'ANALYSIS', 'score': 0.7670884132385254},
#  {'label': 'ANALYSIS', 'score': 0.4486870765686035},
#  {'label': 'ANALYSIS', 'score': 0.39210832118988037},
#  {'label': 'ANALYSIS', 'score': 0.878980278968811},
#  {'label': 'PRE_RELIED', 'score': 0.5870798826217651},
#  {'label': 'ANALYSIS', 'score': 0.5832863450050354},
#  {'label': 'ANALYSIS', 'score': 0.5573270320892334},
#  {'label': 'ANALYSIS', 'score': 0.7320914268493652},
#  {'label': 'ANALYSIS', 'score': 0.8935971856117249},
#  {'label': 'ANALYSIS', 'score': 0.43916893005371094},
#  {'label': 'ANALYSIS', 'score': 0.6486321687698364},
#  {'label': 'RPC', 'score': 0.6161073446273804},
#  {'label': 'RPC', 'score': 0.9345160126686096},
#  {'label': 'RPC', 'score': 0.9166293740272522},
#  {'label': 'NONE', 'score': 0.9753095507621765},
#  {'label': 'PREAMBLE', 'score': 0.988753080368042},
#  {'label': 'PREAMBLE', 'score': 0.9896016716957092},
#  {'label': 'PREAMBLE', 'score': 0.9907351732254028},
#  {'label': 'PREAMBLE', 'score': 0.9903828501701355},
#  {'label': 'PREAMBLE', 'score': 0.9914430975914001},
#  {'label': 'PREAMBLE', 'score': 0.9757550358772278},
#  {'label': 'FAC', 'score': 0.7863880395889282},
#  {'label': 'FAC', 'score': 0.9708069562911987},
#  {'label': 'FAC', 'score': 0.9009554386138916},
#  {'label': 'ANALYSIS', 'score': 0.6007702350616455},
#  {'label': 'FAC', 'score': 0.9588121175765991},
#  {'label': 'ANALYSIS', 'score': 0.382330983877182},
#  {'label': 'FAC', 'score': 0.48496896028518677},
#  {'label': 'ARG_RESPONDENT', 'score': 0.31498628854751587},
#  {'label': 'RPC', 'score': 0.7473455667495728},
#  {'label': 'PREAMBLE', 'score': 0.9873980283737183},
#  {'label': 'PREAMBLE', 'score': 0.9526377320289612},
#  {'label': 'ARG_PETITIONER', 'score': 0.5795523524284363},
#  {'label': 'ANALYSIS', 'score': 0.6867581009864807},
#  {'label': 'ANALYSIS', 'score': 0.6313546299934387},
#  {'label': 'ARG_PETITIONER', 'score': 0.5060012936592102},
#  {'label': 'ANALYSIS', 'score': 0.8071354627609253},
#  {'label': 'ARG_PETITIONER', 'score': 0.5969616174697876},
#  {'label': 'ARG_PETITIONER', 'score': 0.6516568064689636},
#  {'label': 'ANALYSIS', 'score': 0.6408421993255615},
#  {'label': 'ARG_PETITIONER', 'score': 0.5132540464401245},
#  {'label': 'NONE', 'score': 0.9165496826171875},
#  {'label': 'ISSUE', 'score': 0.5270094871520996},
#  {'label': 'ISSUE', 'score': 0.8800667524337769},
#  {'label': 'ANALYSIS', 'score': 0.7989060878753662},
#  {'label': 'ANALYSIS', 'score': 0.8178597688674927},
#  {'label': 'ANALYSIS', 'score': 0.8118240833282471},
#  {'label': 'ANALYSIS', 'score': 0.7197706699371338},
#  {'label': 'ANALYSIS', 'score': 0.7027907371520996},
#  {'label': 'RATIO', 'score': 0.5623148083686829},
#  {'label': 'RPC', 'score': 0.9502221941947937},
#  {'label': 'RPC', 'score': 0.9437315464019775},
#  {'label': 'NONE', 'score': 0.9746057391166687},
#  {'label': 'PREAMBLE', 'score': 0.988917350769043},
#  {'label': 'PREAMBLE', 'score': 0.989669144153595},
#  {'label': 'PREAMBLE', 'score': 0.98428875207901},
#  {'label': 'PREAMBLE', 'score': 0.9908825159072876},
#  {'label': 'PREAMBLE', 'score': 0.9919450879096985},
#  {'label': 'PREAMBLE', 'score': 0.9899425506591797},
#  {'label': 'PREAMBLE', 'score': 0.9878124594688416},
#  {'label': 'PREAMBLE', 'score': 0.9890598058700562},
#  {'label': 'PREAMBLE', 'score': 0.9840059876441956},
#  {'label': 'FAC', 'score': 0.8955699801445007},
#  {'label': 'NONE', 'score': 0.6284875273704529},
#  {'label': 'FAC', 'score': 0.9654049277305603},
#  {'label': 'FAC', 'score': 0.7461642026901245},
#  {'label': 'FAC', 'score': 0.6953792572021484},
#  {'label': 'FAC', 'score': 0.7631271481513977},
#  {'label': 'FAC', 'score': 0.504181981086731},
#  {'label': 'ARG_PETITIONER', 'score': 0.5576003193855286},
#  {'label': 'ANALYSIS', 'score': 0.864128053188324},
#  {'label': 'ARG_PETITIONER', 'score': 0.6818113923072815},
#  {'label': 'ARG_PETITIONER', 'score': 0.7077832818031311},
#  {'label': 'ANALYSIS', 'score': 0.6301829814910889},
#  {'label': 'ANALYSIS', 'score': 0.797355055809021},
#  {'label': 'RATIO', 'score': 0.2898293435573578},
#  {'label': 'ARG_PETITIONER', 'score': 0.7230260968208313},
#  {'label': 'ARG_PETITIONER', 'score': 0.6515673398971558},
#  {'label': 'ARG_PETITIONER', 'score': 0.3817456066608429},
#  {'label': 'ARG_PETITIONER', 'score': 0.5659511089324951},
#  {'label': 'ARG_RESPONDENT', 'score': 0.4574775695800781},
#  {'label': 'ANALYSIS', 'score': 0.4575214982032776},
#  {'label': 'ARG_PETITIONER', 'score': 0.6711437702178955},
#  {'label': 'ARG_PETITIONER', 'score': 0.6505189538002014},
#  {'label': 'ARG_PETITIONER', 'score': 0.48585712909698486},
#  {'label': 'NONE', 'score': 0.5811737775802612},
#  {'label': 'ANALYSIS', 'score': 0.9113304615020752},
#  {'label': 'ANALYSIS', 'score': 0.6363036632537842},
#  {'label': 'ANALYSIS', 'score': 0.8874521851539612},
#  {'label': 'ANALYSIS', 'score': 0.677501380443573},
#  {'label': 'ANALYSIS', 'score': 0.9217420816421509},
#  {'label': 'ANALYSIS', 'score': 0.7125381231307983},
#  {'label': 'RATIO', 'score': 0.5439932942390442},
#  {'label': 'ANALYSIS', 'score': 0.7369893193244934},
#  {'label': 'ANALYSIS', 'score': 0.8541134595870972},
#  {'label': 'ANALYSIS', 'score': 0.7492973804473877},
#  {'label': 'ANALYSIS', 'score': 0.5188431143760681},
#  {'label': 'ANALYSIS', 'score': 0.7925572395324707},
#  {'label': 'ANALYSIS', 'score': 0.9164802432060242},
#  {'label': 'RATIO', 'score': 0.6726676225662231},
#  {'label': 'RATIO', 'score': 0.5679702162742615},
#  {'label': 'RPC', 'score': 0.9344984889030457},
#  {'label': 'RPC', 'score': 0.9362974166870117},
#  {'label': 'RPC', 'score': 0.8742380738258362},
#  {'label': 'NONE', 'score': 0.9744307398796082},
#  {'label': 'PREAMBLE', 'score': 0.9901100993156433},
#  {'label': 'PREAMBLE', 'score': 0.9922171831130981},
#  {'label': 'PREAMBLE', 'score': 0.9480383396148682},
#  {'label': 'PREAMBLE', 'score': 0.9922116994857788},
#  {'label': 'PREAMBLE', 'score': 0.9911720156669617},
#  {'label': 'PREAMBLE', 'score': 0.9877497553825378},
#  {'label': 'PREAMBLE', 'score': 0.9900505542755127},
#  {'label': 'PREAMBLE', 'score': 0.9728929400444031},
#  {'label': 'PREAMBLE', 'score': 0.9889266490936279},
#  {'label': 'RPC', 'score': 0.5688337683677673},
#  {'label': 'PREAMBLE', 'score': 0.986205518245697},
#  {'label': 'FAC', 'score': 0.6786784529685974},
#  {'label': 'FAC', 'score': 0.7826340794563293},
#  {'label': 'RLC', 'score': 0.7900516390800476},
#  {'label': 'FAC', 'score': 0.9665842652320862},
#  {'label': 'FAC', 'score': 0.9695560932159424},
#  {'label': 'FAC', 'score': 0.809766948223114},
#  {'label': 'FAC', 'score': 0.8849114179611206},
#  {'label': 'ANALYSIS', 'score': 0.8535904288291931},
#  {'label': 'RLC', 'score': 0.7911178469657898},
#  {'label': 'FAC', 'score': 0.8746199607849121},
#  {'label': 'FAC', 'score': 0.9442334771156311},
#  {'label': 'FAC', 'score': 0.8308179974555969},
#  {'label': 'FAC', 'score': 0.9208909869194031},
#  {'label': 'FAC', 'score': 0.7649776339530945},
#  {'label': 'FAC', 'score': 0.8931816220283508},
#  {'label': 'FAC', 'score': 0.7733847498893738},
#  {'label': 'FAC', 'score': 0.5316994190216064},
#  {'label': 'FAC', 'score': 0.7594571709632874},
#  {'label': 'FAC', 'score': 0.7552616000175476},
#  {'label': 'FAC', 'score': 0.9605200886726379},
#  {'label': 'FAC', 'score': 0.880254864692688},
#  {'label': 'FAC', 'score': 0.7695415616035461},
#  {'label': 'FAC', 'score': 0.6211122870445251},
#  {'label': 'FAC', 'score': 0.6293408274650574},
#  {'label': 'PREAMBLE', 'score': 0.357525110244751},
#  {'label': 'FAC', 'score': 0.7013859152793884},
#  {'label': 'FAC', 'score': 0.6561086773872375},
#  {'label': 'FAC', 'score': 0.7679452896118164},
#  {'label': 'FAC', 'score': 0.5938987135887146},
#  {'label': 'FAC', 'score': 0.668594479560852},
#  {'label': 'FAC', 'score': 0.7967206239700317},
#  {'label': 'FAC', 'score': 0.836890697479248},
#  {'label': 'FAC', 'score': 0.7301931977272034},
#  {'label': 'FAC', 'score': 0.819991946220398},
#  {'label': 'FAC', 'score': 0.7294180393218994},
#  {'label': 'ANALYSIS', 'score': 0.47947025299072266},
#  {'label': 'FAC', 'score': 0.9215835332870483},
#  {'label': 'FAC', 'score': 0.9058153033256531},
#  {'label': 'FAC', 'score': 0.7264386415481567},
#  {'label': 'FAC', 'score': 0.8705260753631592},
#  {'label': 'FAC', 'score': 0.8481600880622864},
#  {'label': 'ANALYSIS', 'score': 0.8509223461151123},
#  {'label': 'FAC', 'score': 0.8898472785949707},
#  {'label': 'FAC', 'score': 0.6225436925888062},
#  {'label': 'ANALYSIS', 'score': 0.7867872714996338},
#  {'label': 'FAC', 'score': 0.8879647850990295},
#  {'label': 'FAC', 'score': 0.7207872271537781},
#  {'label': 'FAC', 'score': 0.6532107591629028},
#  {'label': 'FAC', 'score': 0.9309206604957581},
#  {'label': 'FAC', 'score': 0.5131443738937378},
#  {'label': 'FAC', 'score': 0.47843408584594727},
#  {'label': 'FAC', 'score': 0.8861070275306702},
#  {'label': 'FAC', 'score': 0.8114941120147705},
#  {'label': 'FAC', 'score': 0.91750168800354},
#  {'label': 'FAC', 'score': 0.8336374163627625},
#  {'label': 'ANALYSIS', 'score': 0.7798299193382263},
#  {'label': 'ANALYSIS', 'score': 0.867496132850647},
#  {'label': 'ANALYSIS', 'score': 0.9166236519813538},
#  {'label': 'ANALYSIS', 'score': 0.49977174401283264},
#  {'label': 'ANALYSIS', 'score': 0.8786633014678955},
#  {'label': 'ANALYSIS', 'score': 0.8869441747665405},
#  {'label': 'ANALYSIS', 'score': 0.7401785254478455},
#  {'label': 'ANALYSIS', 'score': 0.8689965605735779},
#  {'label': 'ANALYSIS', 'score': 0.7583079934120178},
#  {'label': 'ANALYSIS', 'score': 0.8281304836273193},
#  {'label': 'ANALYSIS', 'score': 0.859330415725708},
#  {'label': 'ANALYSIS', 'score': 0.8583475351333618},
#  {'label': 'FAC', 'score': 0.6650875806808472},
#  {'label': 'FAC', 'score': 0.6188095211982727},
#  {'label': 'FAC', 'score': 0.5779141783714294},
#  {'label': 'ANALYSIS', 'score': 0.8659600019454956},
#  {'label': 'ANALYSIS', 'score': 0.9229328036308289},
#  {'label': 'ANALYSIS', 'score': 0.9315954446792603},
#  {'label': 'ANALYSIS', 'score': 0.9274188280105591},
#  {'label': 'ANALYSIS', 'score': 0.8562842011451721},
#  {'label': 'ANALYSIS', 'score': 0.9101279973983765},
#  {'label': 'ANALYSIS', 'score': 0.9323775172233582},
#  {'label': 'ANALYSIS', 'score': 0.8957388997077942},
#  {'label': 'ANALYSIS', 'score': 0.9373035430908203},
#  {'label': 'FAC', 'score': 0.5680986046791077},
#  {'label': 'ANALYSIS', 'score': 0.7327958345413208},
#  {'label': 'ANALYSIS', 'score': 0.934424877166748},
#  {'label': 'ANALYSIS', 'score': 0.777271032333374},
#  {'label': 'ANALYSIS', 'score': 0.9012563228607178},
#  {'label': 'ANALYSIS', 'score': 0.9324583411216736},
#  {'label': 'ANALYSIS', 'score': 0.8776693940162659},
#  {'label': 'ANALYSIS', 'score': 0.8333961367607117},
#  {'label': 'ANALYSIS', 'score': 0.8634647727012634},
#  {'label': 'ANALYSIS', 'score': 0.9284729957580566},
#  {'label': 'ANALYSIS', 'score': 0.9372497200965881},
#  {'label': 'ANALYSIS', 'score': 0.847877562046051},
#  {'label': 'ANALYSIS', 'score': 0.8917744159698486},
#  {'label': 'ANALYSIS', 'score': 0.6927932500839233},
#  {'label': 'ANALYSIS', 'score': 0.8851796984672546},
#  {'label': 'ANALYSIS', 'score': 0.7857624292373657},
#  {'label': 'ANALYSIS', 'score': 0.8917744159698486},
#  {'label': 'FAC', 'score': 0.6463068723678589},
#  {'label': 'ANALYSIS', 'score': 0.833432674407959},
#  {'label': 'ANALYSIS', 'score': 0.8596702218055725},
#  {'label': 'ANALYSIS', 'score': 0.725146472454071},
#  {'label': 'ANALYSIS', 'score': 0.7339822053909302},
#  {'label': 'ANALYSIS', 'score': 0.9409511685371399},
#  {'label': 'ANALYSIS', 'score': 0.9151013493537903},
#  {'label': 'ANALYSIS', 'score': 0.5184871554374695},
#  {'label': 'NONE', 'score': 0.8763738870620728},
#  {'label': 'ARG_PETITIONER', 'score': 0.574654221534729},
#  {'label': 'ANALYSIS', 'score': 0.8930639624595642},
#  {'label': 'ARG_PETITIONER', 'score': 0.5889161825180054},
#  {'label': 'ANALYSIS', 'score': 0.8381491899490356},
#  {'label': 'ANALYSIS', 'score': 0.5227660536766052},
#  {'label': 'ANALYSIS', 'score': 0.9145188331604004},
#  {'label': 'ARG_PETITIONER', 'score': 0.5368680953979492},
#  {'label': 'ARG_PETITIONER', 'score': 0.5520810484886169},
#  {'label': 'ANALYSIS', 'score': 0.8876156806945801},
#  {'label': 'ANALYSIS', 'score': 0.41229474544525146},
#  {'label': 'ANALYSIS', 'score': 0.8920276165008545},
#  {'label': 'ARG_PETITIONER', 'score': 0.5416873097419739},
#  {'label': 'ARG_PETITIONER', 'score': 0.6813270449638367},
#  {'label': 'ANALYSIS', 'score': 0.8996145725250244},
#  {'label': 'ARG_PETITIONER', 'score': 0.5818539261817932},
#  {'label': 'ANALYSIS', 'score': 0.8842032551765442},
#  {'label': 'ARG_PETITIONER', 'score': 0.38986024260520935},
#  {'label': 'ANALYSIS', 'score': 0.6034814715385437},
#  {'label': 'ARG_PETITIONER', 'score': 0.6454077959060669},
#  {'label': 'ARG_PETITIONER', 'score': 0.5680842995643616},
#  {'label': 'ANALYSIS', 'score': 0.31363487243652344},
#  {'label': 'ARG_PETITIONER', 'score': 0.46656182408332825},
#  {'label': 'ANALYSIS', 'score': 0.36853429675102234},
#  {'label': 'ANALYSIS', 'score': 0.9190129041671753},
#  {'label': 'ARG_PETITIONER', 'score': 0.515317976474762},
#  {'label': 'ANALYSIS', 'score': 0.9167741537094116},
#  {'label': 'ANALYSIS', 'score': 0.8585951924324036},
#  {'label': 'ANALYSIS', 'score': 0.7939338088035583},
#  {'label': 'RATIO', 'score': 0.6390526294708252},
#  {'label': 'ARG_PETITIONER', 'score': 0.6062119603157043},
#  {'label': 'ANALYSIS', 'score': 0.9133180379867554},
#  {'label': 'ANALYSIS', 'score': 0.9201368689537048},
#  {'label': 'ANALYSIS', 'score': 0.9146220684051514},
#  {'label': 'ANALYSIS', 'score': 0.8884025812149048},
#  {'label': 'STA', 'score': 0.8958265781402588},
#  {'label': 'ANALYSIS', 'score': 0.8223849534988403},
#  {'label': 'ANALYSIS', 'score': 0.9295233488082886},
#  {'label': 'ANALYSIS', 'score': 0.9470073580741882},
#  {'label': 'ANALYSIS', 'score': 0.930766224861145},
#  {'label': 'ANALYSIS', 'score': 0.40741679072380066},
#  {'label': 'ANALYSIS', 'score': 0.8876966238021851},
#  {'label': 'ANALYSIS', 'score': 0.8822258114814758},
#  {'label': 'ANALYSIS', 'score': 0.7991029024124146},
#  {'label': 'ANALYSIS', 'score': 0.882067084312439},
#  {'label': 'ANALYSIS', 'score': 0.8351461291313171},
#  {'label': 'ANALYSIS', 'score': 0.6509791016578674},
#  {'label': 'ANALYSIS', 'score': 0.9295918345451355},
#  {'label': 'ANALYSIS', 'score': 0.8816500902175903},
#  {'label': 'ANALYSIS', 'score': 0.898270308971405},
#  {'label': 'ANALYSIS', 'score': 0.9092777371406555},
#  {'label': 'ANALYSIS', 'score': 0.6929088234901428},
#  {'label': 'ANALYSIS', 'score': 0.8288583159446716},
#  {'label': 'ANALYSIS', 'score': 0.8040256500244141},
#  {'label': 'ANALYSIS', 'score': 0.844201922416687},
#  {'label': 'ANALYSIS', 'score': 0.7367411255836487},
#  {'label': 'ANALYSIS', 'score': 0.48699241876602173},
#  {'label': 'RPC', 'score': 0.8798984885215759},
#  {'label': 'RPC', 'score': 0.8672869801521301},
#  {'label': 'ARG_PETITIONER', 'score': 0.6178650259971619},
#  {'label': 'RPC', 'score': 0.9351857900619507},
#  {'label': 'NONE', 'score': 0.8246445655822754},
#  {'label': 'NONE', 'score': 0.9759058952331543},
#  {'label': 'PREAMBLE', 'score': 0.9893290400505066},
#  {'label': 'PREAMBLE', 'score': 0.9925008416175842},
#  {'label': 'PREAMBLE', 'score': 0.9619510173797607},
#  {'label': 'FAC', 'score': 0.951108992099762},
#  {'label': 'FAC', 'score': 0.9585494995117188},
#  {'label': 'FAC', 'score': 0.956825315952301},
#  {'label': 'FAC', 'score': 0.9580708742141724},
#  {'label': 'FAC', 'score': 0.9408805966377258},
#  {'label': 'FAC', 'score': 0.906914472579956},
#  {'label': 'FAC', 'score': 0.7119048237800598},
#  {'label': 'FAC', 'score': 0.8611505031585693},
#  {'label': 'FAC', 'score': 0.9366739392280579},
#  {'label': 'FAC', 'score': 0.8335713744163513},
#  {'label': 'FAC', 'score': 0.9325437545776367},
#  {'label': 'ANALYSIS', 'score': 0.5619865655899048},
#  {'label': 'FAC', 'score': 0.9176000356674194},
#  {'label': 'FAC', 'score': 0.9327789545059204},
#  {'label': 'FAC', 'score': 0.9455549716949463},
#  {'label': 'FAC', 'score': 0.494874507188797},
#  {'label': 'FAC', 'score': 0.8583647608757019},
#  {'label': 'FAC', 'score': 0.5240889191627502},
#  {'label': 'FAC', 'score': 0.4182809293270111},
#  {'label': 'ARG_PETITIONER', 'score': 0.5693255662918091},
#  {'label': 'ANALYSIS', 'score': 0.806892991065979},
#  {'label': 'ANALYSIS', 'score': 0.7877344489097595},
#  {'label': 'FAC', 'score': 0.9743524193763733},
#  {'label': 'ANALYSIS', 'score': 0.3575129508972168},
#  {'label': 'ARG_PETITIONER', 'score': 0.3142780661582947},
#  {'label': 'RATIO', 'score': 0.2865476906299591},
#  {'label': 'ARG_RESPONDENT', 'score': 0.35557207465171814},
#  {'label': 'FAC', 'score': 0.6954589486122131},
#  {'label': 'FAC', 'score': 0.5883562564849854},
#  {'label': 'ANALYSIS', 'score': 0.8215634226799011},
#  {'label': 'ANALYSIS', 'score': 0.7945734858512878},
#  {'label': 'RATIO', 'score': 0.4290977120399475},
#  {'label': 'ANALYSIS', 'score': 0.6367825865745544},
#  {'label': 'ARG_RESPONDENT', 'score': 0.28871822357177734},
#  {'label': 'ANALYSIS', 'score': 0.6219472885131836},
#  {'label': 'FAC', 'score': 0.7768751978874207},
#  {'label': 'ANALYSIS', 'score': 0.6770545840263367},
#  {'label': 'RATIO', 'score': 0.5938862562179565},
#  {'label': 'RPC', 'score': 0.899257242679596},
#  {'label': 'RPC', 'score': 0.9568545818328857},
#  {'label': 'RPC', 'score': 0.9600487351417542},
#  {'label': 'RPC', 'score': 0.945032000541687},
#  {'label': 'RPC', 'score': 0.953933596611023},
#  {'label': 'RPC', 'score': 0.9573535919189453},
#  {'label': 'NONE', 'score': 0.9744543433189392},
#  {'label': 'PREAMBLE', 'score': 0.9849247336387634},
#  {'label': 'PREAMBLE', 'score': 0.9895926713943481},
#  {'label': 'PREAMBLE', 'score': 0.9910581111907959},
#  {'label': 'PREAMBLE', 'score': 0.7856890559196472},
#  {'label': 'PREAMBLE', 'score': 0.9355807900428772},
#  {'label': 'PREAMBLE', 'score': 0.9907267093658447},
#  {'label': 'PREAMBLE', 'score': 0.989302933216095},
#  {'label': 'FAC', 'score': 0.9635943174362183},
#  {'label': 'FAC', 'score': 0.9478841423988342},
#  {'label': 'FAC', 'score': 0.9285779595375061},
#  {'label': 'FAC', 'score': 0.8535064458847046},
#  {'label': 'FAC', 'score': 0.8946409225463867},
#  {'label': 'FAC', 'score': 0.769841730594635},
#  {'label': 'FAC', 'score': 0.9342856407165527},
#  {'label': 'FAC', 'score': 0.9577977061271667},
#  {'label': 'FAC', 'score': 0.95745849609375},
#  {'label': 'FAC', 'score': 0.9408248662948608},
#  {'label': 'ISSUE', 'score': 0.9619326591491699},
#  {'label': 'FAC', 'score': 0.5207963585853577},
#  {'label': 'FAC', 'score': 0.6285243034362793},
#  {'label': 'ANALYSIS', 'score': 0.5656318664550781},
#  {'label': 'FAC', 'score': 0.9285779595375061},
#  {'label': 'FAC', 'score': 0.8563946485519409},
#  {'label': 'ANALYSIS', 'score': 0.6873328685760498},
#  {'label': 'ANALYSIS', 'score': 0.7528176307678223},
#  {'label': 'ANALYSIS', 'score': 0.5050468444824219},
#  {'label': 'ANALYSIS', 'score': 0.5961157083511353},
#  {'label': 'ANALYSIS', 'score': 0.8985646963119507},
#  {'label': 'ANALYSIS', 'score': 0.7456744313240051},
#  {'label': 'ANALYSIS', 'score': 0.6955668330192566},
#  {'label': 'ANALYSIS', 'score': 0.7297707796096802},
#  {'label': 'ANALYSIS', 'score': 0.6939824223518372},
#  {'label': 'ANALYSIS', 'score': 0.5445475578308105},
#  {'label': 'ANALYSIS', 'score': 0.937978982925415},
#  {'label': 'ANALYSIS', 'score': 0.7890954613685608},
#  {'label': 'ANALYSIS', 'score': 0.7955517768859863},
#  {'label': 'ANALYSIS', 'score': 0.7846007347106934},
#  {'label': 'ANALYSIS', 'score': 0.8032197952270508},
#  {'label': 'RATIO', 'score': 0.4371320605278015},
#  {'label': 'RATIO', 'score': 0.6841374039649963},
#  {'label': 'RPC', 'score': 0.9328827857971191},
#  {'label': 'RPC', 'score': 0.9429452419281006},
#  {'label': 'RPC', 'score': 0.9431719183921814},
#  {'label': 'RPC', 'score': 0.9443590044975281},
#  {'label': 'NONE', 'score': 0.9625107049942017},
#  {'label': 'NONE', 'score': 0.9250506162643433},
#  {'label': 'NONE', 'score': 0.9636561870574951},
#  {'label': 'NONE', 'score': 0.9746014475822449},
#  {'label': 'NONE', 'score': 0.9787671566009521},
#  {'label': 'NONE', 'score': 0.9763699173927307},
#  {'label': 'NONE', 'score': 0.9661141633987427},
#  {'label': 'NONE', 'score': 0.9791544675827026},
#  {'label': 'NONE', 'score': 0.9661141633987427},
#  {'label': 'NONE', 'score': 0.9636561870574951},
#  {'label': 'PREAMBLE', 'score': 0.9897184371948242},
#  {'label': 'PREAMBLE', 'score': 0.9897352457046509},
#  {'label': 'PREAMBLE', 'score': 0.9899731874465942},
#  {'label': 'PREAMBLE', 'score': 0.9591658115386963},
#  {'label': 'PREAMBLE', 'score': 0.9904147386550903},
#  {'label': 'PREAMBLE', 'score': 0.991635799407959},
#  {'label': 'FAC', 'score': 0.9306932091712952},
#  {'label': 'FAC', 'score': 0.9612489342689514},
#  {'label': 'ARG_PETITIONER', 'score': 0.4766232371330261},
#  {'label': 'ANALYSIS', 'score': 0.7673447728157043},
#  {'label': 'ARG_PETITIONER', 'score': 0.43680518865585327},
#  {'label': 'FAC', 'score': 0.7525163888931274},
#  {'label': 'ARG_PETITIONER', 'score': 0.49804478883743286},
#  {'label': 'ARG_RESPONDENT', 'score': 0.22616848349571228},
#  {'label': 'ARG_PETITIONER', 'score': 0.4183185398578644},
#  {'label': 'FAC', 'score': 0.6035779118537903},
#  {'label': 'FAC', 'score': 0.7580361366271973},
#  {'label': 'ARG_RESPONDENT', 'score': 0.39469650387763977},
#  {'label': 'ARG_RESPONDENT', 'score': 0.24382366240024567},
#  {'label': 'ARG_PETITIONER', 'score': 0.47440141439437866},
#  {'label': 'ISSUE', 'score': 0.8849285840988159},
#  {'label': 'ISSUE', 'score': 0.8800667524337769},
#  {'label': 'NONE', 'score': 0.9240726828575134},
#  {'label': 'ANALYSIS', 'score': 0.9250198006629944},
#  {'label': 'ANALYSIS', 'score': 0.8666279911994934},
#  {'label': 'FAC', 'score': 0.3990229368209839},
#  {'label': 'FAC', 'score': 0.37357693910598755},
#  {'label': 'FAC', 'score': 0.763164758682251},
#  {'label': 'FAC', 'score': 0.9214469790458679},
#  {'label': 'ANALYSIS', 'score': 0.9374245405197144},
#  {'label': 'ANALYSIS', 'score': 0.604844868183136},
#  {'label': 'FAC', 'score': 0.7149547934532166},
#  {'label': 'RATIO', 'score': 0.6103546619415283},
#  {'label': 'ANALYSIS', 'score': 0.7772886753082275},
#  {'label': 'RPC', 'score': 0.957346498966217},
#  {'label': 'RPC', 'score': 0.9563024044036865},
#  {'label': 'NONE', 'score': 0.9549581408500671},
#  {'label': 'NONE', 'score': 0.9334447979927063},
#  {'label': 'NONE', 'score': 0.9228724837303162},
#  {'label': 'PREAMBLE', 'score': 0.9875854253768921},
#  {'label': 'PREAMBLE', 'score': 0.9895239472389221},
#  {'label': 'PREAMBLE', 'score': 0.9913741946220398},
#  {'label': 'PREAMBLE', 'score': 0.9866069555282593},
#  {'label': 'PREAMBLE', 'score': 0.991496205329895},
#  {'label': 'PREAMBLE', 'score': 0.9918288588523865},
#  {'label': 'PREAMBLE', 'score': 0.9298698306083679},
#  {'label': 'PREAMBLE', 'score': 0.9851241707801819},
#  {'label': 'FAC', 'score': 0.904967188835144},
#  {'label': 'FAC', 'score': 0.8866374492645264},
#  {'label': 'FAC', 'score': 0.9541510343551636},
#  {'label': 'FAC', 'score': 0.9561252593994141},
#  {'label': 'FAC', 'score': 0.9281434416770935},
#  {'label': 'FAC', 'score': 0.484529048204422},
#  {'label': 'ANALYSIS', 'score': 0.8688271641731262},
#  {'label': 'FAC', 'score': 0.8738542795181274},
#  {'label': 'FAC', 'score': 0.9000652432441711},
#  {'label': 'RLC', 'score': 0.794655442237854},
#  {'label': 'RLC', 'score': 0.6804909706115723},
#  {'label': 'FAC', 'score': 0.9545392394065857},
#  {'label': 'ARG_PETITIONER', 'score': 0.6750927567481995},
#  {'label': 'ANALYSIS', 'score': 0.8628485798835754},
#  {'label': 'ANALYSIS', 'score': 0.8110567331314087},
#  {'label': 'FAC', 'score': 0.4557093381881714},
#  {'label': 'ANALYSIS', 'score': 0.8917372226715088},
#  {'label': 'ANALYSIS', 'score': 0.7321262359619141},
#  {'label': 'ANALYSIS', 'score': 0.42635634541511536},
#  {'label': 'ANALYSIS', 'score': 0.46499133110046387},
#  {'label': 'ANALYSIS', 'score': 0.8532352447509766},
#  {'label': 'ANALYSIS', 'score': 0.8342998623847961},
#  {'label': 'ARG_RESPONDENT', 'score': 0.4611552655696869},
#  {'label': 'ANALYSIS', 'score': 0.7935711145401001},
#  {'label': 'ANALYSIS', 'score': 0.5200338363647461},
#  {'label': 'ANALYSIS', 'score': 0.8013163805007935},
#  {'label': 'ANALYSIS', 'score': 0.6813748478889465},
#  {'label': 'ANALYSIS', 'score': 0.8376946449279785},
#  {'label': 'ANALYSIS', 'score': 0.7213472723960876},
#  {'label': 'ANALYSIS', 'score': 0.6302935481071472},
#  {'label': 'ANALYSIS', 'score': 0.7797496914863586},
#  {'label': 'ANALYSIS', 'score': 0.403367280960083},
#  {'label': 'RPC', 'score': 0.9141903519630432},
#  {'label': 'RPC', 'score': 0.9462469816207886},
#  {'label': 'NONE', 'score': 0.971771776676178},
#  {'label': 'PREAMBLE', 'score': 0.989137589931488},
#  {'label': 'PREAMBLE', 'score': 0.9909273386001587},
#  {'label': 'PREAMBLE', 'score': 0.9907351732254028},
#  {'label': 'PREAMBLE', 'score': 0.9912214279174805},
#  {'label': 'PREAMBLE', 'score': 0.9880726337432861},
#  {'label': 'PREAMBLE', 'score': 0.9916232228279114},
#  {'label': 'PREAMBLE', 'score': 0.9908636212348938},
#  {'label': 'PREAMBLE', 'score': 0.9905417561531067},
#  {'label': 'PREAMBLE', 'score': 0.9894842505455017},
#  {'label': 'PREAMBLE', 'score': 0.981338620185852},
#  {'label': 'PREAMBLE', 'score': 0.991709291934967},
#  {'label': 'PREAMBLE', 'score': 0.9678367376327515},
#  {'label': 'RPC', 'score': 0.7981250286102295},
#  {'label': 'PREAMBLE', 'score': 0.9830335974693298},
#  {'label': 'NONE', 'score': 0.923561155796051},
#  {'label': 'FAC', 'score': 0.9512125253677368},
#  {'label': 'FAC', 'score': 0.9451066851615906},
#  {'label': 'ARG_PETITIONER', 'score': 0.6225823760032654},
#  {'label': 'ARG_PETITIONER', 'score': 0.493049681186676},
#  {'label': 'ARG_PETITIONER', 'score': 0.4635544717311859},
#  {'label': 'ARG_PETITIONER', 'score': 0.657462477684021},
#  {'label': 'PRE_RELIED', 'score': 0.7648583650588989},
#  {'label': 'ANALYSIS', 'score': 0.6673750281333923},
#  {'label': 'ANALYSIS', 'score': 0.5877144932746887},
#  {'label': 'ANALYSIS', 'score': 0.592785656452179},
#  {'label': 'ANALYSIS', 'score': 0.6647106409072876},
#  {'label': 'PRE_RELIED', 'score': 0.6894904375076294},
#  {'label': 'RPC', 'score': 0.9591885209083557},
#  {'label': 'RPC', 'score': 0.9523186087608337},
#  {'label': 'RPC', 'score': 0.9527975916862488},
#  {'label': 'RPC', 'score': 0.9249880313873291},
#  {'label': 'NONE', 'score': 0.9762538075447083},
#  {'label': 'PREAMBLE', 'score': 0.9911722540855408},
#  {'label': 'FAC', 'score': 0.9555555582046509},
#  {'label': 'FAC', 'score': 0.9695180058479309},
#  {'label': 'FAC', 'score': 0.9418739080429077},
#  {'label': 'FAC', 'score': 0.9419074654579163},
#  {'label': 'FAC', 'score': 0.6482906341552734},
#  {'label': 'FAC', 'score': 0.6405687928199768},
#  {'label': 'FAC', 'score': 0.9067800641059875},
#  {'label': 'FAC', 'score': 0.8858147263526917},
#  {'label': 'FAC', 'score': 0.6752305626869202},
#  {'label': 'FAC', 'score': 0.8936283588409424},
#  {'label': 'FAC', 'score': 0.9570102095603943},
#  {'label': 'ANALYSIS', 'score': 0.5244589447975159},
#  {'label': 'ISSUE', 'score': 0.9527762532234192},
#  {'label': 'ISSUE', 'score': 0.9534416794776917},
#  {'label': 'ISSUE', 'score': 0.9562177062034607},
#  {'label': 'ISSUE', 'score': 0.9598143100738525},
#  {'label': 'ISSUE', 'score': 0.9580020308494568},
#  {'label': 'ISSUE', 'score': 0.9571794867515564},
#  {'label': 'ANALYSIS', 'score': 0.4861137270927429},
#  {'label': 'ANALYSIS', 'score': 0.6126254200935364},
#  {'label': 'FAC', 'score': 0.5918530225753784},
#  {'label': 'ANALYSIS', 'score': 0.7372176647186279},
#  {'label': 'ANALYSIS', 'score': 0.8936300277709961},
#  {'label': 'ANALYSIS', 'score': 0.840059220790863},
#  {'label': 'ANALYSIS', 'score': 0.7065173983573914},
#  {'label': 'ANALYSIS', 'score': 0.7336340546607971},
#  {'label': 'ANALYSIS', 'score': 0.6329239010810852},
#  {'label': 'RLC', 'score': 0.3670588731765747},
#  {'label': 'RPC', 'score': 0.9444658756256104},
#  {'label': 'NONE', 'score': 0.8951051831245422},
#  {'label': 'NONE', 'score': 0.9766555428504944},
#  {'label': 'PREAMBLE', 'score': 0.8835046291351318},
#  {'label': 'PREAMBLE', 'score': 0.935882031917572},
#  {'label': 'PREAMBLE', 'score': 0.97939133644104},
#  {'label': 'PREAMBLE', 'score': 0.9912618398666382},
#  {'label': 'PREAMBLE', 'score': 0.6899699568748474},
#  {'label': 'PREAMBLE', 'score': 0.9906895160675049},
#  {'label': 'FAC', 'score': 0.619949221611023},
#  {'label': 'ANALYSIS', 'score': 0.664107620716095},
#  {'label': 'RLC', 'score': 0.6742664575576782},
#  {'label': 'RLC', 'score': 0.5106133818626404},
#  {'label': 'PREAMBLE', 'score': 0.990431010723114},
#  {'label': 'ANALYSIS', 'score': 0.4538804292678833},
#  {'label': 'ANALYSIS', 'score': 0.5270548462867737},
#  {'label': 'FAC', 'score': 0.9164162874221802},
#  {'label': 'ANALYSIS', 'score': 0.7066447734832764},
#  {'label': 'ANALYSIS', 'score': 0.618320107460022},
#  {'label': 'PREAMBLE', 'score': 0.6642393469810486},
#  {'label': 'PREAMBLE', 'score': 0.9872051477432251},
#  {'label': 'ANALYSIS', 'score': 0.6891537308692932},
#  {'label': 'ANALYSIS', 'score': 0.6369172930717468},
#  {'label': 'ANALYSIS', 'score': 0.7452570199966431},
#  {'label': 'ANALYSIS', 'score': 0.6568194031715393},
#  {'label': 'PREAMBLE', 'score': 0.9830974340438843},
#  {'label': 'PREAMBLE', 'score': 0.9643224477767944},
#  {'label': 'PREAMBLE', 'score': 0.7327569127082825},
#  {'label': 'PREAMBLE', 'score': 0.9307889342308044},
#  {'label': 'PREAMBLE', 'score': 0.8115405440330505},
#  {'label': 'PRE_RELIED', 'score': 0.44948363304138184},
#  {'label': 'PREAMBLE', 'score': 0.9830858707427979},
#  {'label': 'PREAMBLE', 'score': 0.9786345958709717},
#  {'label': 'PREAMBLE', 'score': 0.727952241897583},
#  {'label': 'PREAMBLE', 'score': 0.9883928894996643},
#  {'label': 'NONE', 'score': 0.8815088272094727},
#  {'label': 'NONE', 'score': 0.9671462774276733},
#  {'label': 'NONE', 'score': 0.9511388540267944},
#  {'label': 'NONE', 'score': 0.9576169848442078},
#  {'label': 'NONE', 'score': 0.9534183144569397},
#  {'label': 'NONE', 'score': 0.958640456199646},
#  {'label': 'NONE', 'score': 0.9168339371681213},
#  {'label': 'ANALYSIS', 'score': 0.8412321209907532},
#  {'label': 'FAC', 'score': 0.7209159135818481},
#  {'label': 'FAC', 'score': 0.9726884365081787},
#  {'label': 'FAC', 'score': 0.9536086320877075},
#  {'label': 'FAC', 'score': 0.9472000002861023},
#  {'label': 'FAC', 'score': 0.5792858600616455},
#  {'label': 'ANALYSIS', 'score': 0.8983399868011475},
#  {'label': 'FAC', 'score': 0.822655975818634},
#  {'label': 'FAC', 'score': 0.637757420539856},
#  {'label': 'ARG_PETITIONER', 'score': 0.5530577301979065},
#  {'label': 'ARG_PETITIONER', 'score': 0.6280136704444885},
#  {'label': 'FAC', 'score': 0.3832021653652191},
#  {'label': 'ANALYSIS', 'score': 0.592600405216217},
#  {'label': 'FAC', 'score': 0.7706343531608582},
#  {'label': 'ANALYSIS', 'score': 0.9050448536872864},
#  {'label': 'ARG_PETITIONER', 'score': 0.4694422483444214},
#  {'label': 'ANALYSIS', 'score': 0.5383120179176331},
#  {'label': 'ARG_PETITIONER', 'score': 0.5019747018814087},
#  {'label': 'ANALYSIS', 'score': 0.6542237997055054},
#  {'label': 'ANALYSIS', 'score': 0.8232145309448242},
#  {'label': 'ANALYSIS', 'score': 0.8087168335914612},
#  {'label': 'ANALYSIS', 'score': 0.6570701003074646},
#  {'label': 'ANALYSIS', 'score': 0.7333517670631409},
#  {'label': 'ANALYSIS', 'score': 0.667293131351471},
#  {'label': 'ANALYSIS', 'score': 0.7658186554908752},
#  {'label': 'ANALYSIS', 'score': 0.7322840094566345},
#  {'label': 'FAC', 'score': 0.9594704508781433},
#  {'label': 'ANALYSIS', 'score': 0.8519816398620605},
#  {'label': 'ANALYSIS', 'score': 0.842627763748169},
#  {'label': 'ANALYSIS', 'score': 0.6744765043258667},
#  {'label': 'ANALYSIS', 'score': 0.8842825293540955},
#  {'label': 'ANALYSIS', 'score': 0.633620023727417},
#  {'label': 'ANALYSIS', 'score': 0.6749208569526672},
#  {'label': 'ANALYSIS', 'score': 0.7967588901519775},
#  {'label': 'ANALYSIS', 'score': 0.7223912477493286},
#  {'label': 'ANALYSIS', 'score': 0.7836931943893433},
#  {'label': 'FAC', 'score': 0.7040165066719055},
#  {'label': 'ANALYSIS', 'score': 0.9123397469520569},
#  {'label': 'FAC', 'score': 0.943794846534729},
#  {'label': 'ANALYSIS', 'score': 0.7240765690803528},
#  {'label': 'ANALYSIS', 'score': 0.8397706151008606},
#  {'label': 'ANALYSIS', 'score': 0.7884776592254639},
#  {'label': 'ANALYSIS', 'score': 0.8578304052352905},
#  {'label': 'ANALYSIS', 'score': 0.7298223376274109},
#  {'label': 'ANALYSIS', 'score': 0.9560056328773499},
#  {'label': 'ANALYSIS', 'score': 0.7156392335891724},
#  {'label': 'FAC', 'score': 0.8528072834014893},
#  {'label': 'ANALYSIS', 'score': 0.8316789865493774},
#  {'label': 'ANALYSIS', 'score': 0.6603882908821106},
#  {'label': 'ANALYSIS', 'score': 0.7514106631278992},
#  {'label': 'FAC', 'score': 0.8223832845687866},
#  {'label': 'ANALYSIS', 'score': 0.7539214491844177},
#  {'label': 'ANALYSIS', 'score': 0.9387915134429932},
#  {'label': 'ANALYSIS', 'score': 0.8088405728340149},
#  {'label': 'ANALYSIS', 'score': 0.733204185962677},
#  {'label': 'ANALYSIS', 'score': 0.5853384137153625},
#  {'label': 'ANALYSIS', 'score': 0.9302014708518982},
#  {'label': 'ANALYSIS', 'score': 0.9185220003128052},
#  {'label': 'ANALYSIS', 'score': 0.7656447291374207},
#  {'label': 'ANALYSIS', 'score': 0.8479965329170227},
#  {'label': 'ANALYSIS', 'score': 0.8799624443054199},
#  {'label': 'ANALYSIS', 'score': 0.9029287695884705},
#  {'label': 'ANALYSIS', 'score': 0.6988606452941895},
#  {'label': 'ANALYSIS', 'score': 0.8762302398681641},
#  {'label': 'ANALYSIS', 'score': 0.6970084309577942},
#  {'label': 'ANALYSIS', 'score': 0.5365143418312073},
#  {'label': 'PRE_RELIED', 'score': 0.5007266998291016},
#  {'label': 'PRE_RELIED', 'score': 0.5287323594093323},
#  {'label': 'ANALYSIS', 'score': 0.5877867937088013},
#  {'label': 'ANALYSIS', 'score': 0.8604853749275208},
#  {'label': 'ANALYSIS', 'score': 0.7811708450317383},
#  {'label': 'ANALYSIS', 'score': 0.9207533597946167},
#  {'label': 'ANALYSIS', 'score': 0.6117408871650696},
#  {'label': 'ANALYSIS', 'score': 0.9122578501701355},
#  {'label': 'FAC', 'score': 0.9520437717437744},
#  {'label': 'ANALYSIS', 'score': 0.8007701635360718},
#  {'label': 'ANALYSIS', 'score': 0.7328933477401733},
#  {'label': 'ANALYSIS', 'score': 0.4912598133087158},
#  {'label': 'ANALYSIS', 'score': 0.8878675103187561},
#  {'label': 'ANALYSIS', 'score': 0.49553921818733215},
#  {'label': 'ANALYSIS', 'score': 0.4597932994365692},
#  {'label': 'ANALYSIS', 'score': 0.618320107460022},
#  {'label': 'RLC', 'score': 0.4116385877132416},
#  {'label': 'ANALYSIS', 'score': 0.7383648157119751},
#  {'label': 'ANALYSIS', 'score': 0.7452570199966431},
#  {'label': 'ANALYSIS', 'score': 0.6799176335334778},
#  {'label': 'ANALYSIS', 'score': 0.7446348667144775},
#  {'label': 'ANALYSIS', 'score': 0.6782822012901306},
#  {'label': 'ANALYSIS', 'score': 0.7188196182250977},
#  {'label': 'ANALYSIS', 'score': 0.6580209136009216},
#  {'label': 'RPC', 'score': 0.8691642880439758},
#  {'label': 'RPC', 'score': 0.8177885413169861},
#  {'label': 'RPC', 'score': 0.4743894636631012},
#  {'label': 'PREAMBLE', 'score': 0.9886937737464905},
#  {'label': 'PREAMBLE', 'score': 0.9881773591041565},
#  {'label': 'PREAMBLE', 'score': 0.9846717715263367},
#  {'label': 'PREAMBLE', 'score': 0.9857462644577026},
#  {'label': 'PREAMBLE', 'score': 0.9917349815368652},
#  {'label': 'PREAMBLE', 'score': 0.9837164878845215},
#  {'label': 'PREAMBLE', 'score': 0.9865248203277588},
#  {'label': 'PREAMBLE', 'score': 0.9902890920639038},
#  {'label': 'PREAMBLE', 'score': 0.9917556047439575},
#  {'label': 'PREAMBLE', 'score': 0.9909014701843262},
#  {'label': 'PREAMBLE', 'score': 0.9879105091094971},
#  {'label': 'PREAMBLE', 'score': 0.9820026159286499},
#  {'label': 'PREAMBLE', 'score': 0.986086905002594},
#  {'label': 'PREAMBLE', 'score': 0.9637856483459473},
#  {'label': 'PREAMBLE', 'score': 0.9713359475135803},
#  {'label': 'PREAMBLE', 'score': 0.7390738725662231},
#  {'label': 'PREAMBLE', 'score': 0.992354154586792},
#  {'label': 'PREAMBLE', 'score': 0.9105423092842102},
#  {'label': 'PREAMBLE', 'score': 0.9279224276542664},
#  {'label': 'PREAMBLE', 'score': 0.9851419925689697},
#  {'label': 'PREAMBLE', 'score': 0.9877139329910278},
#  {'label': 'NONE', 'score': 0.8845563530921936},
#  {'label': 'NONE', 'score': 0.9309443235397339},
#  {'label': 'NONE', 'score': 0.9591120481491089},
#  {'label': 'NONE', 'score': 0.8214242458343506},
#  {'label': 'PREAMBLE', 'score': 0.7746521830558777},
#  {'label': 'FAC', 'score': 0.802635669708252},
#  {'label': 'FAC', 'score': 0.9477018713951111},
#  {'label': 'ARG_PETITIONER', 'score': 0.30657389760017395},
#  {'label': 'FAC', 'score': 0.6187368035316467},
#  {'label': 'FAC', 'score': 0.6297516226768494},
#  {'label': 'FAC', 'score': 0.9103676080703735},
#  {'label': 'FAC', 'score': 0.8289089202880859},
#  {'label': 'FAC', 'score': 0.8201743364334106},
#  {'label': 'ANALYSIS', 'score': 0.45522749423980713},
#  {'label': 'FAC', 'score': 0.7319415211677551},
#  {'label': 'ANALYSIS', 'score': 0.7188830971717834},
#  {'label': 'FAC', 'score': 0.7106496691703796},
#  {'label': 'FAC', 'score': 0.945995032787323},
#  {'label': 'FAC', 'score': 0.9622864723205566},
#  {'label': 'FAC', 'score': 0.7092246413230896},
#  {'label': 'FAC', 'score': 0.6326265931129456},
#  {'label': 'FAC', 'score': 0.9396404027938843},
#  {'label': 'ANALYSIS', 'score': 0.7959251999855042},
#  {'label': 'ANALYSIS', 'score': 0.7182840704917908},
#  {'label': 'ANALYSIS', 'score': 0.6345597505569458},
#  {'label': 'FAC', 'score': 0.9001485109329224},
#  {'label': 'ANALYSIS', 'score': 0.4893653094768524},
#  {'label': 'FAC', 'score': 0.7420538067817688},
#  {'label': 'FAC', 'score': 0.5923276543617249},
#  {'label': 'ARG_PETITIONER', 'score': 0.565828263759613},
#  {'label': 'ANALYSIS', 'score': 0.5391800999641418},
#  ...]

# %%
rr_test = open('rr_test.json')
rrtest_dataset = json.load(rr_test)
for rec in rrtest_dataset:
  for idx, ele in enumerate(rec['annotations'][0]['result']): 
    ele['value']['labels'][0] = output[idx]['label']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-45e3357a1d0e> in <module>
#       3 for rec in rrtest_dataset:
#       4   for idx, ele in enumerate(rec['annotations'][0]['result']):
# ----> 5     ele['value']['labels'][0] = output[idx]['label']
#
# NameError: name 'output' is not defined

# %%
out_file = open("myfile.json", "w")
json.dump(rrtest_dataset,out_file, indent=6)
out_file.close()

# %%
train_dataset.extend(dev_dataset)
random.shuffle(train_dataset)

# %%
import sent2vec
from sentence_transformers import SentenceTransformer
# model = sent2vec.Sent2vecModel()
# model.load_model('./semantic-segmentation/infer/sent2vec.bin')

model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')


for count, rec in enumerate(train_dataset):
    if rec['annotations'][0]['result'] == []:
         continue
    with open(f'./semantic-segmentation/data/pretrained_emb/{rec["id"]}.txt','w+') as f:
            for ele in rec['annotations'][0]['result']: 
                processed_text = ele['value']['text']
                processed_text = processed_text.replace('\n', ' ')
                processed_text = re.sub(' {2,}', ' ', processed_text)
                processed_text = processed_text.lower()
                label = ele['value']['labels'][0]
                emb = model.encode(processed_text)
                processed_text = " ".join([str(i) for i in  emb])
                f.write(f'{processed_text}\t{label}\n')
print(count)
# Out:
# 276

# %%
len(train_dataset)
# Out:
# 277

# %%
with open(f'./semantic-segmentation/cat.txt','w+') as f:
    f.write('Legal\t')
    for rec in train_dataset:
        if rec['annotations'][0]['result'] == []:
            continue
        f.write(f'{rec["id"]} ')

# %%
test = open('rr_test.json')
test_dataset = json.load(test)
for count, rec in enumerate(test_dataset):
    if rec['annotations'][0]['result'] == []:
         print('yes')
         continue
    with open(f'./semantic-segmentation/infer/data/{rec["id"]}.txt','w+') as f:
            for ele in rec['annotations'][0]['result']: 
                processed_text = ele['value']['text']
                processed_text = processed_text.replace('\n', ' ')
                processed_text = re.sub(' {2,}', ' ', processed_text)
                f.write(f'{ele["id"]}\t{processed_text}\n')

# %%
with open('./semantic-segmentation/infer/pred_ids.txt','r') as f:
    ids = json.load(f)

# %%
preds = dict()
with open('./semantic-segmentation/infer/predictions.txt','r') as f:
    for line in f:
        arr = line.split('\t')
        arr[1] = arr[1].replace('\n','')
        preds[int(arr[0])] = arr[1].split(',')
len(preds)
# Out:
# 50

# %%
for key, value in preds.items():
    with open(f'./semantic-segmentation/infer/data/{key}.txt') as f:
        text = f.readlines()
        if(len(value) != len(text)):
            print(key)

# %%
for rec in test_dataset:
    lab = preds[int(rec['id'])]
    i=0

    for ele in rec['annotations'][0]['result']:
        if ele['id'] in ids[str(rec['id'])]:
            ele['value']['labels'][0] = lab[i]
            i+=1
        else:
            ele['value']['labels'][0] = "NONE"

# %%
out_file = open("submissionSTemb.json", "w")
json.dump(test_dataset,out_file, indent=6)
out_file.close()

# %%
import glob
for filename in glob.glob('./semantic-segmentation/data/text/*.txt'):
    with open(filename, 'r') as f:
        arr = [l.strip() for l in f]
        print(arr)
        break

# %%
import sent2vec
model = sent2vec.Sent2vecModel()
model.load_model('./semantic-segmentation/infer/sent2vec.bin')
emb = model.embed_sentence("once upon a time .") 
emb
# Out:
# array([[ 0.3827696 , -0.18814288, -0.52750456,  0.0993287 ,  0.87292796,
#         -0.61967283, -0.671658  ,  0.1319409 ,  0.33635676,  0.301886  ,
#         -0.2546241 , -0.20579605,  0.24103308, -0.23798686, -0.08603713,
#          0.36622182,  0.5031561 , -0.29081622, -0.42823997, -0.14480692,
#          0.5837328 ,  0.01628563, -0.17452843, -0.53246737, -0.18692206,
#          0.4429304 ,  0.50153977, -0.29309112, -0.0926116 ,  1.0668284 ,
#          0.3150685 ,  0.00236383, -0.02039053, -0.38179708, -0.2799668 ,
#         -0.501665  , -0.21791966, -0.27207178,  0.6428038 ,  0.03471715,
#          0.06431601,  0.95592946,  0.63953406, -0.32514006,  0.5782566 ,
#          0.12229088,  0.53094846,  0.3701749 , -0.21859041,  0.599999  ,
#          0.44534752, -0.07129437,  0.06976022,  0.24513888, -0.5483347 ,
#          0.1396512 ,  0.62140644, -1.1654739 , -0.5549987 ,  0.5456811 ,
#          0.547042  , -0.15461458,  0.10945165,  0.5032859 ,  0.07112101,
#          0.76943856, -0.18670817,  0.34202027,  1.0600268 , -0.5281709 ,
#          0.15105692,  0.05084624, -0.20215435,  0.03133776, -0.55253863,
#          0.3238105 ,  0.44063702, -0.43200678, -0.2528005 , -0.31660762,
#         -0.05835358, -0.23402745, -0.22639424,  0.24488589, -0.41805533,
#         -0.01430536, -0.29953256,  0.09241144,  0.09774254,  0.31662023,
#          0.3863073 , -0.27233103,  0.7973255 , -0.2812816 , -0.43044913,
#         -0.09652404, -0.55718577,  0.13963261,  0.269503  , -0.04590641,
#          0.19633207, -0.22810227,  0.08956349,  0.24765886, -0.01619334,
#         -0.02429796, -1.0103365 ,  0.38604984,  0.35217282,  0.11518243,
#         -0.21827416,  0.3499224 , -0.71991706,  0.56801546,  0.35876307,
#          0.22789617, -0.01416025, -0.60904163,  0.19809984,  0.21724369,
#          0.1700422 ,  0.02746021, -0.05333199,  0.3419812 , -0.7560017 ,
#          0.22560917,  0.3560193 ,  0.12180052, -0.2855928 , -0.11765197,
#          0.24043843,  0.52684605,  0.18412289,  0.15550643,  0.20311485,
#         -0.05663035, -0.07872979, -0.21293862,  0.01678382, -0.33922285,
#          0.1714595 ,  0.5943223 , -0.11461788,  0.10300855,  0.3647174 ,
#         -0.22471407,  0.08015982, -0.5013312 , -0.37813795,  0.3475219 ,
#         -0.3169675 , -0.39285225, -0.00298253, -0.701957  , -0.13017137,
#          0.29695398, -0.4116327 ,  0.51734954,  0.2555187 ,  0.12335339,
#         -0.4613544 , -0.5719426 ,  0.43358693, -0.0182269 ,  0.04530644,
#          0.11111959, -0.35882938, -0.19377053, -0.21568745, -0.43575945,
#          0.38694897,  0.46289396, -0.30481276, -0.09692917, -0.33795696,
#          0.22878332, -0.06603048,  0.09911028,  0.31485152,  0.48132172,
#          0.45237267, -0.13303207, -0.00806534, -0.3284511 ,  0.32472467,
#         -0.00174656,  0.2322566 ,  0.33198252,  0.03374843, -0.13221003,
#          0.5366923 , -0.2206973 ,  0.08063786, -0.12847787, -0.3656031 ,
#          0.4321306 ,  0.15281735, -0.43607464, -0.2204737 , -0.03277058]],
#       dtype=float32)

# %%
len(emb[0])
# Out:
# 200

# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
embeddings = model.encode("gello ajsda")
print(embeddings)
# Out:
# [ 3.23235542e-02  2.76791155e-02 -1.79122910e-02 -3.78156528e-02
#   5.51560111e-02  1.03917988e-02  5.57913398e-03  2.40380820e-02
#   4.48452719e-02  3.34757715e-02  4.10673060e-02 -5.51949218e-02
#   5.09915203e-02  3.94745357e-03  2.13389099e-02 -4.15916741e-02
#   8.36438965e-03 -9.72388126e-03 -6.58859238e-02 -3.77151258e-02
#  -3.80968228e-02 -3.30935145e-04 -3.35505907e-03  2.88008489e-02
#   4.87894341e-02 -6.14981726e-03  4.92815208e-03 -1.96512714e-02
#   4.00273968e-03  8.38761702e-02 -1.54896630e-02 -1.56159159e-02
#  -2.65765190e-02 -3.43008619e-03  1.97007284e-06 -6.20464887e-03
#  -1.76943501e-03 -1.54109783e-02  1.38676278e-02 -2.41489410e-02
#  -9.84460860e-02 -3.73590477e-02 -5.04393578e-02 -6.53715432e-02
#  -1.68510713e-02 -6.50279000e-02  2.77446397e-02 -6.16434105e-02
#  -3.36593240e-02  2.40848772e-02  1.13347005e-02 -1.23019628e-01
#   1.35630909e-02 -1.11678503e-02  7.98444152e-02 -7.20923543e-02
#  -1.17533952e-02 -4.16300185e-02 -3.58461626e-02 -1.49025340e-02
#   8.09680205e-03  4.69611548e-02 -2.21129525e-02 -1.63341369e-02
#   1.63646229e-02 -7.56834541e-03 -2.00649444e-02 -5.20722289e-03
#   4.71625850e-02  4.71768677e-02  7.17469305e-02 -2.22158227e-02
#   1.95998345e-02  9.08694565e-02  5.72954724e-03  5.01289917e-03
#  -4.23406474e-02  4.29129638e-02 -6.02901774e-03 -3.97502854e-02
#   2.99493019e-02  5.76361977e-02  1.42523656e-02  9.31893475e-03
#   4.01833095e-02  8.53071511e-02  5.17782802e-03 -2.24621501e-02
#   5.82066402e-02 -2.45629065e-02 -6.68930402e-03  1.49556035e-02
#   2.86492263e-03  5.66088781e-02 -4.28015515e-02  4.47674328e-03
#  -2.53351376e-04 -8.52790624e-02  2.34015100e-02 -6.73909709e-02
#   4.28489931e-02 -1.65871903e-02  1.21339194e-01  3.17458697e-02
#  -1.04923248e-02  2.38429196e-02 -2.93472270e-03 -2.96567678e-02
#  -1.06571345e-02 -2.18360741e-02 -7.89083075e-03 -1.66405533e-02
#  -4.19646911e-02  2.97025614e-03  1.56709235e-02  5.94345592e-02
#  -3.43029946e-02  2.48836111e-02  2.34390032e-02  7.44285136e-02
#  -5.78491166e-02  1.55591369e-02  8.28238763e-03 -6.64137378e-02
#  -3.34631763e-02 -2.32043071e-03 -4.85374928e-02  3.40011083e-02
#  -2.84017995e-02 -7.71242287e-03  3.46866921e-02  4.90375236e-02
#  -3.66672128e-02  6.55264966e-03  1.73392426e-02  5.59822023e-02
#  -1.97480675e-02 -6.70061707e-02 -4.66784611e-02 -3.58574949e-02
#  -1.33266603e-03 -2.95810290e-02 -3.87819111e-03 -3.84240272e-03
#   2.00696867e-02 -2.29833797e-02  1.07954554e-02 -7.54338726e-02
#  -4.81675714e-02  3.30961868e-02  6.19730428e-02  2.00738665e-02
#  -4.16764952e-02  2.39664763e-02 -2.44714618e-02  3.41605134e-02
#   3.96714099e-02 -2.39698030e-02 -4.11236286e-02  1.88180283e-02
#  -1.83649492e-02  1.56015567e-02  5.16365357e-02  5.40130073e-04
#  -3.08805387e-02 -1.61062200e-02 -3.88956256e-02  5.09462394e-02
#  -3.34498622e-02 -1.10614505e-02 -1.76600087e-02 -8.65736697e-03
#   4.93583344e-02  1.36608547e-02  1.72226578e-02 -7.46896444e-03
#  -1.00303134e-02  6.33259118e-02 -1.74289271e-02 -1.96546130e-02
#   7.12211505e-02 -1.39067486e-01  7.30139837e-02  1.49393501e-02
#   3.58839296e-02  4.43755277e-02 -3.99419516e-02  8.75597969e-02
#  -2.69110035e-03  8.91661085e-03  6.07352555e-02 -1.85361563e-03
#  -4.80593815e-02  3.49300690e-02 -4.01000157e-02 -1.87121704e-02
#   1.57646555e-02 -7.57381096e-02  4.57342016e-03  1.57273635e-02
#  -4.87812283e-03 -3.96604203e-02  6.83392808e-02 -4.98555005e-02
#  -3.81143279e-02  3.25839012e-03  1.21194264e-02 -1.41577087e-02
#  -5.01974933e-02 -3.66753154e-02 -9.81562138e-02 -1.69427376e-02
#   4.37382655e-03 -5.10042300e-03  3.44770737e-02  5.98977320e-02
#   5.23693627e-04  5.31359464e-02 -2.72428412e-02  9.75682586e-02
#  -5.21466089e-03 -3.48610873e-03  6.26173168e-02 -1.89173333e-02
#   5.87433651e-02 -2.81983465e-02  2.25767028e-02  1.44621432e-02
#   1.59590114e-02  5.67032630e-03 -6.69178925e-03  3.10158753e-03
#   4.18159366e-02  2.69599333e-02  9.38052032e-03  3.43404822e-02
#   3.47811617e-02 -4.24977019e-02 -3.92140113e-02 -2.44120657e-02
#  -1.93478391e-02 -4.08864357e-02  1.94216613e-02 -1.17388358e-02
#   1.07359245e-01  4.15219506e-03  1.83892883e-02  1.89540833e-02
#   2.40755901e-02 -2.03105044e-02  1.16942003e-02 -2.49092262e-02
#  -1.14086391e-02 -1.45809334e-02  1.92785226e-02 -1.33072874e-02
#  -3.48432064e-02  4.99325246e-02  2.44201049e-02 -3.43561508e-02
#   6.18435554e-02 -1.34617323e-02  3.65642197e-02 -2.37414390e-02
#   6.94549754e-02 -5.99911250e-03 -1.09757052e-03  2.83496138e-02
#  -2.89006177e-02  1.11658266e-02  2.68250480e-02 -5.77720907e-03
#   3.76610719e-02 -1.57843456e-02 -1.71292797e-02 -7.77029665e-03
#  -8.07684194e-03 -3.15426327e-02 -4.68684323e-02 -3.58584858e-02
#   2.70645656e-02  5.13378158e-02 -3.46459914e-03  1.08746262e-02
#   3.10628172e-02  2.26944294e-02  3.35807838e-02 -4.77023907e-02
#  -3.08939200e-02 -6.06021360e-02 -3.34965624e-02 -1.98727828e-02
#  -1.47020109e-02 -5.14750183e-03 -2.09673750e-03  6.24311790e-02
#  -7.76308402e-03  6.00860752e-02 -1.67514775e-02 -2.29433216e-02
#   4.85205799e-02  4.46393155e-03  3.13636474e-02 -2.29219291e-02
#   1.08851464e-02  1.52619174e-02 -1.28992023e-02 -1.83423068e-02
#   2.79612895e-02 -4.58497629e-02  2.45279912e-02  1.08144153e-03
#  -1.49192726e-02 -3.01912567e-03  7.70632271e-03 -2.99300421e-02
#   7.40026543e-03  3.31223896e-03 -6.58038259e-03  5.54013886e-02
#   2.42812242e-02  4.94070537e-02 -1.39683727e-02 -1.94886010e-02
#  -2.89867856e-02  9.66728758e-03  2.71880701e-02 -1.95894763e-02
#  -1.81554463e-02 -6.79768622e-02  4.84697707e-02 -2.96476688e-02
#   2.35079937e-02  2.45408062e-02 -3.78560065e-03 -2.83857249e-02
#  -5.33585344e-03 -4.98254038e-02  2.05787644e-02  1.10397758e-02
#   4.38658521e-03  2.42289361e-02  4.45714826e-03  1.24723120e-02
#  -1.85336899e-02 -1.85062345e-02  4.22543101e-03 -8.26880243e-03
#  -7.03764856e-02 -5.30655868e-02  1.53339114e-02 -3.03941742e-02
#  -1.21640032e-02 -2.42546573e-02 -2.78556384e-02 -1.18019255e-02
#  -1.92233667e-04 -4.24046032e-02 -2.18578223e-02  4.59390432e-02
#  -3.37103708e-03 -7.77536677e-03  2.71297875e-03 -2.29414161e-02
#   1.54106226e-02  3.18659879e-02 -3.13808629e-03  1.52442995e-02
#  -1.16331838e-02 -8.78460240e-03  4.28861789e-02  1.73813924e-02
#   1.23743117e-02  1.73859261e-02 -3.19153555e-02 -4.72911075e-02
#  -1.54023459e-02  2.65351031e-02  6.02706484e-02  3.93215865e-02
#   4.48974110e-02  1.85387954e-02  1.48597574e-02 -8.91137682e-03
#  -7.16769649e-03 -1.82695817e-02  1.56929065e-02 -3.38049419e-02
#  -4.82049845e-02  3.63428816e-02  2.68021990e-02  5.66241816e-02
#  -7.19335005e-02 -3.72411832e-02  6.65115891e-03  9.04371962e-03
#   9.25475452e-03  3.54993604e-02 -2.26523522e-02  2.53753290e-02
#   3.87940593e-02  3.38511728e-02 -4.65658456e-02  1.21011054e-02
#   2.00468469e-02  4.08763997e-02  3.21714184e-03  1.81110911e-02
#   3.53596732e-02 -5.21930344e-02  1.86577383e-02 -7.39760250e-02
#  -2.69581880e-02  2.63248235e-02 -2.09607631e-02 -2.44008675e-02
#  -3.24416049e-02 -4.81682681e-02  7.35250069e-04 -1.26949269e-02
#   4.45459262e-02  3.07981055e-02 -2.83172820e-03  4.98391353e-02
#   6.03342243e-02  1.02307228e-02  1.51095958e-02  1.12327617e-02
#  -2.23498959e-02  8.14784225e-03  1.14719914e-02  2.90364423e-03
#   4.39693016e-04 -3.92834693e-02  1.01861218e-02 -7.50294775e-02
#   5.66782728e-02  2.27311682e-02  2.69733276e-03  3.57056444e-04
#  -5.18701412e-02  8.43579043e-03  2.92774849e-02  2.68370677e-02
#   1.63991377e-02 -8.33645985e-02 -3.56566277e-04  5.31075262e-02
#  -7.69700035e-02  3.18043074e-03  3.33137363e-02  1.25083383e-02
#   1.47683444e-02 -1.47366803e-02  5.02558649e-02 -2.07804497e-02
#  -5.84447607e-02 -3.20736133e-02  6.68559782e-03 -4.65127602e-02
#   3.66013609e-02  4.03810069e-02 -1.62258074e-02  2.49851365e-02
#  -3.88164371e-02 -1.00494228e-01 -4.00717650e-03  4.82623018e-02
#   1.80607894e-03 -6.61120936e-02 -1.04306843e-02  9.02739645e-04
#   2.61974838e-02  7.49093592e-02 -1.41122201e-02  1.16406707e-02
#  -3.72457802e-02 -1.04506887e-01  2.70957593e-02 -5.00625046e-03
#  -5.51606389e-03 -5.66754900e-02 -1.14967776e-02 -2.57973857e-02
#   2.00198162e-02 -1.70693640e-02  2.50013154e-02  7.54545908e-03
#   1.88519675e-02  1.81717388e-02  1.31668523e-02 -2.31966656e-02
#  -8.22247006e-03  2.01813988e-02 -5.27625531e-02 -2.56584361e-02
#  -3.51810292e-03 -4.55807559e-02  8.56028199e-02  1.07772844e-02
#   2.80621648e-03  5.63850403e-02  3.39969397e-02  3.80967818e-02
#   1.32222269e-02  3.92397977e-02 -1.03417067e-02 -5.91612980e-02
#  -9.52013209e-03 -2.56226882e-02  1.74756546e-03  4.16921079e-02
#   3.73463482e-02 -3.43098380e-02  3.56860878e-03  1.65590998e-02
#   9.48180072e-03 -5.31832948e-02  2.12011244e-02  2.67244480e-03
#   3.20698880e-02  1.17724184e-02  1.18406778e-02 -3.06662451e-02
#   5.98086743e-03 -2.27750782e-02 -2.53473483e-02 -8.10872111e-03
#   6.31998405e-02  2.81592719e-02  3.13616730e-02 -2.83263181e-03
#  -2.03484837e-02 -2.11249646e-02 -3.39304656e-02  4.75941300e-02
#   4.51292396e-02  1.28929168e-02 -1.95133761e-02 -3.45790177e-03
#  -3.78595516e-02 -5.01629598e-02 -9.40011740e-02 -2.54424009e-02
#   3.87415197e-03  5.75665757e-02  2.70054154e-02  3.89980078e-02
#   1.24433180e-02  7.75341839e-02 -1.08317602e-02  2.00266019e-02
#  -1.01749919e-01  2.45622708e-03 -2.20821500e-02 -7.18201775e-33
#   5.88037074e-04  2.09320970e-02  2.76101623e-02 -3.61726210e-02
#  -5.49834780e-02 -5.14912531e-02 -3.58568341e-03  2.66720634e-02
#  -4.30509374e-02 -9.50076059e-03 -6.30982174e-03 -6.01863489e-02
#   1.73365362e-02 -1.22645556e-03  7.73786148e-03 -3.30964057e-03
#  -6.64726719e-02 -1.23073943e-02  6.83534704e-03 -3.19175236e-02
#  -2.09753253e-02 -5.81339188e-03  8.59763548e-02 -8.12232867e-03
#   1.10843517e-02 -3.64547083e-03 -4.74087298e-02  1.32746492e-02
#   3.33403349e-02 -1.97779592e-02  1.13395145e-02  3.82450148e-02
#  -4.96245036e-03  3.67790312e-02  8.39110184e-03  2.41771881e-02
#   2.95765642e-02  2.14956328e-02  4.03901050e-03  6.03453293e-02
#  -3.05494014e-02  1.42664146e-02 -2.46134208e-04 -1.65792406e-02
#  -4.33204044e-03  4.24258187e-02  3.95462522e-03 -3.92300589e-03
#  -2.85128057e-02 -2.36690715e-02 -3.72751653e-02 -1.59495529e-02
#   6.28796872e-03 -4.10470292e-02  3.23274657e-02  6.15191311e-02
#   1.36475461e-02 -3.91671844e-02  2.14573350e-02 -1.28304176e-02
#  -2.66401954e-02  2.61100545e-03 -2.27300897e-02 -3.36297750e-02
#  -2.23697107e-02 -3.91373271e-03  5.50840013e-02 -3.57353538e-02
#   2.29233541e-02  1.43263284e-02 -9.35690105e-03 -4.62273136e-02
#  -4.00806107e-02  2.53750179e-02 -3.82605419e-02 -2.48348303e-02
#  -2.31067538e-02 -1.19815581e-02  7.15665519e-02  1.69224553e-02
#  -4.32960503e-03 -3.09675150e-02  3.16423899e-03  1.77261233e-02
#  -4.15370986e-02 -7.89003968e-02 -7.41023570e-03  8.65855813e-03
#  -9.08058882e-03 -3.47164012e-02 -2.10654289e-02  3.12496051e-02
#  -3.24287079e-02  1.03047444e-02  1.01560624e-02 -6.21689968e-02
#  -7.02568740e-02  2.63674445e-02  8.15386535e-04  2.17350964e-02
#   2.16403734e-02  6.84216246e-03 -5.51054887e-02  6.94193095e-02
#  -1.11345695e-02  2.59097144e-02  1.98541321e-02 -1.62585229e-02
#  -6.03017882e-02  1.14832306e-03 -2.48552226e-02  1.81143228e-02
#   1.81279555e-02  1.66675895e-02 -2.11918447e-03  2.23566312e-02
#  -2.59551536e-02  4.19103093e-02  3.82858003e-03  3.99504416e-02
#   4.94939089e-02 -1.05159640e-01 -1.20480275e-02  4.28340621e-02
#  -3.52707691e-02  2.38199160e-02 -3.78060266e-02  1.29980466e-03
#  -2.11128164e-02  3.28771174e-02  3.73873040e-02 -5.99064343e-02
#   2.68219907e-07 -4.37454283e-02  2.15468332e-02 -4.50629070e-02
#  -8.93758237e-02  4.80270237e-02  4.88316379e-02  1.36197768e-02
#   4.65724431e-02 -3.75351124e-02 -1.73109118e-02 -2.08821776e-03
#  -2.01820489e-02 -8.64409562e-03 -2.88315229e-02  4.41104127e-03
#  -4.11698483e-02 -9.12592933e-02 -2.06597298e-02 -2.53114402e-02
#  -3.32819708e-02 -2.29713172e-04  2.04701293e-02  1.40403351e-02
#  -4.57944050e-02 -3.27887461e-02  2.22724527e-02  2.95391940e-02
#   2.14559194e-02 -2.21367497e-02 -3.61744724e-02  3.83050507e-03
#   6.29597306e-02  1.78623665e-02 -2.80029159e-02  3.41898315e-02
#  -5.05712852e-02  2.57165190e-02  1.00890836e-02  2.47401949e-02
#   9.59521160e-02  3.35891955e-02 -2.60791574e-02 -2.42052879e-02
#  -3.13569419e-02  3.23650762e-02  6.72496185e-02 -5.50513789e-02
#   3.47357877e-02 -3.68391387e-02 -4.26899595e-03  4.32771295e-02
#   2.72971317e-02  4.25820565e-03  1.55979125e-02 -2.60536578e-02
#  -2.81824153e-02  2.79034581e-02  1.14667434e-02 -4.59466036e-03
#   5.65790869e-02 -2.89061666e-02  5.94682433e-02 -1.80413015e-02
#   6.75731152e-02  5.40925749e-02 -5.07524759e-02  2.23203097e-02
#   1.88090656e-34 -1.59764886e-02  9.48111620e-03  5.39176986e-02
#   1.13262944e-02 -4.24309745e-02  1.15559688e-02 -3.68701518e-02
#   8.35101027e-03  2.68358123e-02  8.12799856e-03 -3.23868822e-03]

# %%
len(embeddings[0])
# Out:
# 768

# %%
# python3 -u run.py --dataset_size 275 --cat_path cat.txt --print_every 5 --pretrained True --data_path data/pretrained_emb/ --epoch 100 --emb_dim 768 &> out100_sentence_transformer_emb.txt &
# python3 infer.py --pretrained True --model_path infer/modelSTemb.tar --emb_dim 768
